# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1nMaBQ7g88duMECw_B4mH8ruxwnIwVzGP" width=300/>
#
# # ML-1: Exploratory Data Analysis, Visualisation & Modeling
# ## Homework 1: Who is the best singer ever?
#
# **ML-1 Cohort 1** <br>
# **Instructor: Dr. Rahul Dave**<br>
# **Max Score: 100** <br>

# %% [markdown]
# Name of people who have worked on this homework:
# Gladson Vinod and Prasanna

# %% [markdown]
# ## Table of Contents
# * [HW-1: Who is the best singer ever?](#HW-1:-Who-is-the-best-singer-ever?)
#   * [Instructions](##Instructions)
#   * [Learning Goals](##Learning-Goals)
#   * [Q1: Scrape and Parse Wikipedia for Billboard Top 100](##Q1:-Scrape-and-Parse-Wikipedia-for-Billboard-Top-100)
#     * [1.1 Scrape and Parse the Billboard Wikipedia's page for 1970](###1.1-Scrape-and-Parse-the-Billboard-Wikipedia's-page-for-1970)
#     * [1.2 Scrape Billboard Wikipedia's pages from 1992 to 2020](###1.2-Scrape-Billboard-Wikipedia's-pages-from-1992-to-2020)
#     * [1.3 Parse the data](###1.3-Parse-the-data)
#   * [Q2: Construct a year-song-singer dataframe](##Q2:-Construct-a-year-song-singer-dataframe)
#   * [Q3: Scrape and Parse Wikipedia for Information about Artists and Bands](##Q3:-Scrape-and-Parse-Wikipedia-for-Information-about-Artists-and-Bands)
#     * [3.1 Scrape the artist's Wikipedia webpages](###3.1-Scrape-the-artist's-Wikipedia-webpages)
#     * [3.2 Parse the data](###3.2-Parse-the-data)
#   * [Q4: Merging Artist's and Song dataframes](##Q4:-Merging-Artist's-and-Song-dataframes)
#   * [Q5: Pandas and Relational databases](##Q5:-Pandas-and-Relational-databases)
#     * [5.1 Populating the database](###5.1-Populating-the-database)
#     * [5.2 Performing operations on the database](####5.2-Performing-operations-on-the-database)
#       * [5.2.1 Select all singers below the age of 20 whos Zodiac Sign is Scorpio!](####5.2.1-Select-all-singers-below-the-age-of-20-whos-Zodiac-Sign-is-Scorpio!)
#       * [5.2.2 Find the most popular artists with most appearances in Billboard Top 10](####5.2.2-Find-the-most-popular-artists-with-most-appearances-in-Billboard-Top-10)
#       * [5.2.3 Select all songs with ranking less than 6 and order the rows by artist name](####5.2.3-Select-all-songs-with-ranking-less-than-6-and-order-the-rows-by-artist-name)

# %% [markdown]
# ## Instructions

# %% [markdown]
# - This homework should be submitted in pairs.
#
# - Ensure you and your partner together have submitted the homework only once. Multiple submissions of the same work will be penalised and will cost you 2 points.
#
# - Please restart the kernel and run the entire notebook again before you submit.
#
# - Running cells out of order is a common pitfall in Notebooks. To make sure your code works restart the kernel and run the whole notebook again before you submit.
#
# - To work on the homework, you will first need to fork the repository into your GitHub account and clone it to work on it on your local computer. To submit your homework, push your homework into the same GitHub and upload the link on edStem.
#
# - Submit the homework well before the given deadline. Submissions after the deadline will not be graded.
#
# - We have tried to include all the libraries you may need to do the assignment in the imports statement at the top of this notebook. We strongly suggest that you use those and not others as we may not be familiar with them.
#
# - Comment your code well. This would help the graders in case there is any issue with the notebook while running. It is important to remember that the graders will not troubleshoot your code.
#
# - Please use .head() when viewing data. Do not submit a notebook that is **excessively long**.
#
# - In questions that require code to answer, such as "calculate the $R^2$", do not just output the value from a cell. Write a `print()` function that includes a reference to the calculated value, **not hardcoded**. For example:
# ```
# print(f'The R^2 is {R:.4f}')
# ```
# - Your plots should include clear labels for the $x$ and $y$ axes as well as a descriptive title ("MSE plot" is not a descriptive title; "95 % confidence interval of coefficients of polynomial degree 5" is).
#
# - **Ensure you make appropriate plots for all the questions it is applicable to, regardless of it being explicitly asked for.**
#
# <hr style="height:2pt">

# %% [markdown]
# ## Learning Goals

# %% [markdown]
# Billboard Magazine puts out a top 100 list of "singles" every **year**.
# In the next two homeworks, you will scrape Wikipedia to try to understand how the public's taste in music has evolved. You will do this by learning about the best singers and groups from each year as determined by the Billboard top 100 charts.
#
# This homework consists of five main parts:
#
# 1. Scraping and Parsing [Wikipedia's Billboard Top 100 singles](https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2020) list for every year <br>
# 2. Constructing a year-song-singer dataframe from the scraped data
# 3. Scraping and Parsing Wikipedia's information about the Artists from these Songs
# 4. Merging in both the above dataframes
# 5. Using a Relational Database to perform SQL queries

# %% [markdown]
# This homework will help develop your skills in:
#
# - Web page scraping
# - Data cleaning and manipulation
# - Pandas and SQL

# %% [markdown]
# ---

# %%
#Import libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import json
import re
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Q1: Scrape and Parse Wikipedia for Billboard Top 100
# #### [20 Points]

# %% [markdown]
# In this first question you will scrape wikipedia for Billboard's top 100.
#
# We will be using [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/) to transform HTML content into Python data structures. There are other libraries such as [PyQuery](https://pythonhosted.org/pyquery/) (for people who have used [jQuery](https://jquery.com/) that can also be used).

# %% [markdown]
# ### 1.1 Scrape and Parse the Billboard Wikipedia's page for 1970

# %% [markdown]
# Use python's `requests` module to obtain (GET) the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970.
# From this web page, extract the top 100 singles and their rankings.
#
#
# To do this, create a list of dictionaries, 100 of them to be precise, with the following entries: `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# Name this list of dictionaries `songs`.
#
#
# Here, `url` should be the link for the singer or band (observe that on the web page, there is a link for every song and artist), `ranking` is the ranking of the song, `band_singer` should be the name of the artist(s) and `title` should be the title of the song.
#
#
# We are extracting the `url` of the artist(s) to use at a later stage in the homework.

# %% [markdown]
# *Hint:*
# While parsing the HTML, look for the HTML _tr_ (table row) element, but only the one that has a CSS class of _wikitable_. If you look at the page source, you'll see a construct like __class=wikitable__ on the table as seen below:
#
#
#
# ![Wikipage](
# https://drive.google.com/uc?export=view&id=1ntewsqyZVH6_RETloTQgrWIyQJAa_02D)

# %%
#Get the webpage
t1970 = requests.get("http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970")

# %%
#Parsing the webpage
page = t1970.text
print(page[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Billboard Year-End Hot 100 singles of 1970 - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"YBW2YwpAICkAABGAeKwAAACU","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1970","wgTitle":"Billboard Year-End Hot 100 singles of 1970","wgCurRevisionId":956187414,"wgRevisionId":956187414,"wgArticleId":30302961,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use mdy dates from April 2019","Articles with short description","Short description is differ

# %%
soup = BeautifulSoup(page, 'html.parser')
soup.title
# Out:
# <title>Billboard Year-End Hot 100 singles of 1970 - Wikipedia</title>

# %%
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Billboard Year-End Hot 100 singles of 1970 - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"YBW2YwpAICkAABGAeKwAAACU","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1970","wgTitle":"Billboard Year-End Hot 100 singles of 1970","wgCurRevisionId":956187414,"wgRevisionId":956187414,"wgArticleId":30302961,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use mdy dates from April 2019","Articles with short description","Short des

# %%
tables_wikitable = soup.find_all("table", "wikitable")
print(tables_wikitable)
# Out:
# [<table class="wikitable sortable" style="text-align: center">
# <tbody><tr>
# <th scope="col" style="background:#dde;">No.
# </th>
# <th scope="col" style="background:#dde;">Title
# </th>
# <th scope="col" style="background:#dde;">Artist(s)
# </th></tr>
# <tr>
# <td>1</td>
# <td>"<a class="mw-redirect" href="/wiki/Bridge_Over_Troubled_Water_(song)" title="Bridge Over Troubled Water (song)">Bridge Over Troubled Water</a>"</td>
# <td><a href="/wiki/Simon_%26_Garfunkel" title="Simon &amp; Garfunkel">Simon &amp; Garfunkel</a>
# </td></tr>
# <tr>
# <td>2</td>
# <td>"<a href="/wiki/(They_Long_to_Be)_Close_to_You" title="(They Long to Be) Close to You">(They Long to Be) Close to You</a>"</td>
# <td><a href="/wiki/The_Carpenters" title="The Carpenters">The Carpenters</a>
# </td></tr>
# <tr>
# <td>3</td>
# <td>"<a href="/wiki/American_Woman" title="American Woman">American Woman</a>"</td>
# <td><a href="/wiki/The_Guess_Who" title="The Guess Who">The Guess Who</a>
# </td></tr>
# <tr>
# <td>4</td>
# <td>"<a href="/wiki/Raindrops_Keep_Fallin%27_on_My_Head" title="Raindrops Keep Fallin' on My Head">Raindrops Keep Fallin' on My Head</a>"</td>
# <td><a class="mw-redirect" href="/wiki/B.J._Thomas" title="B.J. Thomas">B.J. Thomas</a>
# </td></tr>
# <tr>
# <td>5</td>
# <td>"<a href="/wiki/War_(The_Temptations_song)#Edwin_Starr_version" title="War (The Temptations song)">War</a>"</td>
# <td><a href="/wiki/Edwin_Starr" title="Edwin Starr">Edwin Starr</a>
# </td></tr>
# <tr>
# <td>6</td>
# <td>"<a href="/wiki/Ain%27t_No_Mountain_High_Enough" title="Ain't No Mountain High Enough">Ain't No Mountain High Enough</a>"</td>
# <td><a href="/wiki/Diana_Ross" title="Diana Ross">Diana Ross</a>
# </td></tr>
# <tr>
# <td>7</td>
# <td>"<a class="mw-redirect" href="/wiki/I%27ll_Be_There_(The_Jackson_5_song)" title="I'll Be There (The Jackson 5 song)">I'll Be There</a>"</td>
# <td><a href="/wiki/The_Jackson_5" title="The Jackson 5">The Jackson 5</a>
# </td></tr>
# <tr>
# <td>8</td>
# <td>"<a href="/wiki/Get_Ready_(The_Temptations_song)#Rare_Earth_version" title="Get Ready (The Temptations song)">Get Ready</a>"</td>
# <td><a href="/wiki/Rare_Earth_(band)" title="Rare Earth (band)">Rare Earth</a>
# </td></tr>
# <tr>
# <td>9</td>
# <td>"<a href="/wiki/Let_It_Be_(Beatles_song)" title="Let It Be (Beatles song)">Let It Be</a>"</td>
# <td><a href="/wiki/The_Beatles" title="The Beatles">The Beatles</a>
# </td></tr>
# <tr>
# <td>10</td>
# <td>"<a href="/wiki/Band_of_Gold_(Freda_Payne_song)" title="Band of Gold (Freda Payne song)">Band of Gold</a>"</td>
# <td><a href="/wiki/Freda_Payne" title="Freda Payne">Freda Payne</a>
# </td></tr>
# <tr>
# <td>11</td>
# <td>"<a href="/wiki/Mama_Told_Me_Not_to_Come" title="Mama Told Me Not to Come">Mama Told Me (Not to Come)</a>"</td>
# <td><a href="/wiki/Three_Dog_Night" title="Three Dog Night">Three Dog Night</a>
# </td></tr>
# <tr>
# <td>12</td>
# <td>"<a href="/wiki/Everything_Is_Beautiful" title="Everything Is Beautiful">Everything Is Beautiful</a>"</td>
# <td><a href="/wiki/Ray_Stevens" title="Ray Stevens">Ray Stevens</a>
# </td></tr>
# <tr>
# <td>13</td>
# <td>"<a href="/wiki/Make_It_with_You" title="Make It with You">Make It with You</a>"</td>
# <td><a href="/wiki/Bread_(band)" title="Bread (band)">Bread</a>
# </td></tr>
# <tr>
# <td>14</td>
# <td>"<a href="/wiki/Hitchin%27_a_Ride_(Vanity_Fare_song)" title="Hitchin' a Ride (Vanity Fare song)">Hitchin' a Ride</a>"</td>
# <td><a href="/wiki/Vanity_Fare" title="Vanity Fare">Vanity Fare</a>
# </td></tr>
# <tr>
# <td>15</td>
# <td>"<a href="/wiki/ABC_(The_Jackson_5_song)" title="ABC (The Jackson 5 song)">ABC</a>"</td>
# <td><a href="/wiki/The_Jackson_5" title="The Jackson 5">The Jackson 5</a>
# </td></tr>
# <tr>
# <td>16</td>
# <td>"<a href="/wiki/The_Love_You_Save" title="The Love You Save">The Love You Save</a>"</td>
# <td><a href="/wiki/The_Jackson_5" title="The Jackson 5">The Jackson 5</a>
# </td></tr>
# <tr>
# <td>17</td>
# <td>"<a href="/wiki/Cracklin%27_Rosie" title="Cracklin' Rosie">Cracklin' Rosie</a>"</td>
# <td><a href="/wiki/Neil_Diamond" title="Neil Diamond">Neil Diamond</a>
# </td></tr>
# <tr>
# <td>18</td>
# <td>"<a href="/wiki/Candida_(song)" title="Candida (song)">Candida</a>"</td>
# <td><a href="/wiki/Tony_Orlando_and_Dawn" title="Tony Orlando and Dawn">Dawn</a>
# </td></tr>
# <tr>
# <td>19</td>
# <td>"<a href="/wiki/Thank_You_(Falettinme_Be_Mice_Elf_Agin)" title="Thank You (Falettinme Be Mice Elf Agin)
# <td>"<a href="/wiki/Are_You_Ready%3F_(Pacific_Gas_%26_Electric_song)" title="Are You Ready? (Pacific Gas &amp; Electric song)">Are You Ready?</a>"</td>
# <td><a href="/wiki/Pacific_Gas_%26_Electric_(band)" title="Pacific Gas &amp; Electric (band)">Pacific Gas &amp; Electric</a>
# </td></tr>
# <tr>
# <td>94</td>
# <td>"<a href="/wiki/Woodstock_(song)" title="Woodstock (song)">Woodstock</a>"</td>
# <td><a href="/wiki/Crosby,_Stills,_Nash_%26_Young" title="Crosby, Stills, Nash &amp; Young">Crosby, Stills, Nash &amp; Young</a>
# </td></tr>
# <tr>
# <td>95</td>
# <td>"<a href="/wiki/I%27ll_Never_Fall_in_Love_Again" title="I'll Never Fall in Love Again">I'll Never Fall in Love Again</a>"</td>
# <td><a href="/wiki/Dionne_Warwick" title="Dionne Warwick">Dionne Warwick</a>
# </td></tr>
# <tr>
# <td>96</td>
# <td>"<a class="mw-redirect" href="/wiki/Look_What_They%27ve_Done_to_My_Song_Ma" title="Look What They've Done to My Song Ma">Look What They've Done to My Song Ma</a>"</td>
# <td><a href="/wiki/The_New_Seekers" title="The New Seekers">The New Seekers</a>
# </td></tr>
# <tr>
# <td>97</td>
# <td>"<a class="mw-redirect" href="/wiki/Walk_A_Mile_In_My_Shoes" title="Walk A Mile In My Shoes">Walk A Mile In My Shoes</a>"</td>
# <td><a href="/wiki/Joe_South" title="Joe South">Joe South</a>
# </td></tr>
# <tr>
# <td>98</td>
# <td>"<a class="mw-redirect" href="/wiki/The_Thrill_Is_Gone_(1951_song)" title="The Thrill Is Gone (1951 song)">The Thrill Is Gone</a>"</td>
# <td><a href="/wiki/B.B._King" title="B.B. King">B.B. King</a>
# </td></tr>
# <tr>
# <td>99</td>
# <td>"<a href="/wiki/It%27s_Only_Make_Believe" title="It's Only Make Believe">It's Only Make Believe</a>"</td>
# <td><a href="/wiki/Glen_Campbell" title="Glen Campbell">Glen Campbell</a>
# </td></tr>
# <tr>
# <td>100</td>
# <td>"<a href="/wiki/Call_Me_(Aretha_Franklin_song)" title="Call Me (Aretha Franklin song)">Call Me</a>"</td>
# <td><a href="/wiki/Aretha_Franklin" title="Aretha Franklin">Aretha Franklin</a>
# </td></tr>
# </tbody></table>]

# %%
print(len(tables_wikitable))
# Out:
# 1

# %%
rows = [row for row in tables_wikitable[0].find_all("tr")]
print(rows)
# Out:
# [<tr>
# <th scope="col" style="background:#dde;">No.
# </th>
# <th scope="col" style="background:#dde;">Title
# </th>
# <th scope="col" style="background:#dde;">Artist(s)
# </th></tr>, <tr>
# <td>1</td>
# <td>"<a class="mw-redirect" href="/wiki/Bridge_Over_Troubled_Water_(song)" title="Bridge Over Troubled Water (song)">Bridge Over Troubled Water</a>"</td>
# <td><a href="/wiki/Simon_%26_Garfunkel" title="Simon &amp; Garfunkel">Simon &amp; Garfunkel</a>
# </td></tr>, <tr>
# <td>2</td>
# <td>"<a href="/wiki/(They_Long_to_Be)_Close_to_You" title="(They Long to Be) Close to You">(They Long to Be) Close to You</a>"</td>
# <td><a href="/wiki/The_Carpenters" title="The Carpenters">The Carpenters</a>
# </td></tr>, <tr>
# <td>3</td>
# <td>"<a href="/wiki/American_Woman" title="American Woman">American Woman</a>"</td>
# <td><a href="/wiki/The_Guess_Who" title="The Guess Who">The Guess Who</a>
# </td></tr>, <tr>
# <td>4</td>
# <td>"<a href="/wiki/Raindrops_Keep_Fallin%27_on_My_Head" title="Raindrops Keep Fallin' on My Head">Raindrops Keep Fallin' on My Head</a>"</td>
# <td><a class="mw-redirect" href="/wiki/B.J._Thomas" title="B.J. Thomas">B.J. Thomas</a>
# </td></tr>, <tr>
# <td>5</td>
# <td>"<a href="/wiki/War_(The_Temptations_song)#Edwin_Starr_version" title="War (The Temptations song)
# <td><a href="/wiki/Joe_South" title="Joe South">Joe South</a>
# </td></tr>, <tr>
# <td>98</td>
# <td>"<a class="mw-redirect" href="/wiki/The_Thrill_Is_Gone_(1951_song)" title="The Thrill Is Gone (1951 song)">The Thrill Is Gone</a>"</td>
# <td><a href="/wiki/B.B._King" title="B.B. King">B.B. King</a>
# </td></tr>, <tr>
# <td>99</td>
# <td>"<a href="/wiki/It%27s_Only_Make_Believe" title="It's Only Make Believe">It's Only Make Believe</a>"</td>
# <td><a href="/wiki/Glen_Campbell" title="Glen Campbell">Glen Campbell</a>
# </td></tr>, <tr>
# <td>100</td>
# <td>"<a href="/wiki/Call_Me_(Aretha_Franklin_song)" title="Call Me (Aretha Franklin song)">Call Me</a>"</td>
# <td><a href="/wiki/Aretha_Franklin" title="Aretha Franklin">Aretha Franklin</a>
# </td></tr>]

# %%
header_row = rows[0]
print(header_row)
# Out:
# <tr>
# <th scope="col" style="background:#dde;">No.
# </th>
# <th scope="col" style="background:#dde;">Title
# </th>
# <th scope="col" style="background:#dde;">Artist(s)
# </th></tr>

# %%
header_columns = [col.get_text() for col in header_row.find_all("th") if col.get_text()]
header_columns
# Out:
# ['No.\n', 'Title\n', 'Artist(s)\n']

# %%
header_columns = [c.strip() for c in header_columns]
header_columns
NoOfHeaderCols = len(header_columns)

# %%
songs = []
for row in rows[1:]:
    songs_dict = {}
    i = 0;
    for value in row.find_all("td"):
        if i == 0:
            songs_dict['Ranking'] = value.text.strip()
        elif i == 1:
            for link in value.findAll('a'):  
                songs_dict['Song'] = link.text.strip()
                songs_dict['Song_URL'] = link.get('href').strip()
        elif i == 2:
             for link in value.findAll('a'):
                 songs_dict['band_singer'] = link.text.strip()
                 songs_dict['URL'] = link.get('href').strip()
        i = i + 1;
    songs.append(songs_dict)

# %%
print(songs)
# Out:
# [{'Ranking': '1', 'Song': 'Bridge Over Troubled Water', 'Song_URL': '/wiki/Bridge_Over_Troubled_Water_(song)', 'band_singer': 'Simon & Garfunkel', 'URL': '/wiki/Simon_%26_Garfunkel'}, {'Ranking': '2', 'Song': '(They Long to Be) Close to You', 'Song_URL': '/wiki/(They_Long_to_Be)_Close_to_You', 'band_singer': 'The Carpenters', 'URL': '/wiki/The_Carpenters'}, {'Ranking': '3', 'Song': 'American Woman', 'Song_URL': '/wiki/American_Woman', 'band_singer': 'The Guess Who', 'URL': '/wiki/The_Guess_Who'}, {'Ranking': '4', 'Song': "Raindrops Keep Fallin' on My Head", 'Song_URL': '/wiki/Raindrops_Keep_Fallin%27_on_My_Head', 'band_singer': 'B.J. Thomas', 'URL': '/wiki/B.J._Thomas'}, {'Ranking': '5', 'Song': 'War', 'Song_URL': '/wiki/War_(The_Temptations_song)#Edwin_Starr_version', 'band_singer': 'Edwin Starr', 'URL': '/wiki/Edwin_Starr'}, {'Ranking': '6', 'Song': "Ain't No Mountain High Enough", 'Song_URL': '/wiki/Ain%27t_No_Mountain_High_Enough', 'band_singer': 'Diana Ross', 'URL': '/wiki/Diana_Ross'}, {'Ranking': '7', 'Song': "I'll Be There", 'Song_URL': '/wiki/I%27ll_Be_There_(The_Jackson_5_song)', 'band_singer': 'The Jackson 5', 'URL': '/wiki/The_Jackson_5'}, {'Ranking': '8', 'Song': 'Get Ready', 'Song_URL': '/wiki/Get_Ready_(The_Temptations_song)#Rare_Earth_
wiki/Ball_of_Confusion_(That%27s_What_the_World_Is_Today)', 'band_singer': 'The Temptations', 'URL': '/wiki/The_Temptations'}, {'Ranking': '25', 'Song': 'Love on a Two-Way Street', 'Song_URL': '/wiki/Love_on_a_Two-Way_Street', 'band_singer': 'The Moments ...

# %% [markdown]
# ### 1.2 Scrape Billboard Wikipedia's pages from 1992 to 2020

# %% [markdown]
# By visiting urls similar to the one for 1970, we can obtain the billboard top 100 for the years 1992 to 2020.
#
# Store the text from your `requests` in a dictionary called `yearstext`.
# This dictionary should have as its keys the years (as integers from 1992 to 2020). The values corresponding to these keys should be the html text downloaded from Wikipedia.<br>
# So, each entry in `yearstext` will look something like this:
#
# ![yearstext](https://drive.google.com/uc?export=view&id=16LNIyznVnAY-N5EN6lsSB9505fXG1-zK)
#
# where the key is 1992 and the value is the HTML at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1992.

# %% [markdown]
# *Hint*:
# Put your requests.get() in a `for` loop and keep appending the text from your requests into the dictionary. Use the `time.sleep` function to wait one second between requests, you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %%
yearstext = {}
for iYear in range(1992, 2020):
    req = requests.get("http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_" + str(iYear))
    yearstext[iYear] = req.text
    time.sleep(1)

# %%
yearstext[2019]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 2019 - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"YBo@-gpAIDAAADIEocsAAABE","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2019","wgTitle":"Billboard Year-End Hot 100 singles of 2019","wgCurRevisionId":1003818858,"wgRevisionId":1003818858,"wgArticleId":62509543,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description matches Wikidata","Wikipedia pages with incorrect protection templates","2019 record charts","Billboard charts","2019 in American music"],"wgPageContentLanguage":"en","wgPageContentModel":\n"wikitext","wgRelevantPageName":"Billboard_Year-End_Hot_100_singles_of_2019","wgRelevantArticleId":62509543,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgPopupsConflictsWithRefTooltipsGadget":!0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q77738352"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":\n"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<meta name="generator" content="MediaWiki 1.36.0-wmf.27"/>\n<meta name="refe ...

# %% [markdown]
# ### 1.3 Parse the data

# %% [markdown]
# Now, write a function `parse_year(year, yeartextdict)` that returns a dictionary `yearinfo`.
# Here `year` should be the integer value of the year, and `yeartextdict` should be the HTML text for the corresponding webpage.
# This function should return a dictionary of the following form:
#
# ```
# {'ranking': 32,
#  'song': ['Hot Boyz (song)'],
#  'songurl': ['/wiki/Hot_Boyz_(song)'],
#  'titletext': '"Hot Boyz"',
#  'band_singer': ['Missy Elliott', 'Nas', 'Eve (rapper)', 'Q-Tip (musician)'],
#  'url': ['/wiki/Missy_Elliott',
#   '/wiki/Nas',
#   '/wiki/Eve_(rapper)',
#   '/wiki/Q-Tip_(musician)']}
# ```
# Notice that the `titletext` is the contents of the table cell, and retains the quotes that wikipedia puts on the single.
#
# Here are some issues that you will need to take care of:
#
# 1.   The example shown above has several artists for a single song. In this case, the `band_singer` and `url` would be a list of items.
#
# 2.   Some singles might even have multiple songs because of the way the industry works:
# ```
# {'ranking': 98,
#  'song': ["You're Makin' Me High", 'Let It Flow (song)'],
#  'songurl': ['/wiki/You%27re_Makin%27_Me_High', '/wiki/Let_It_Flow_(song)'],
#  'titletext': '"You\'re Makin\' Me High" / "Let It Flow"',
#  'band_singer': ['Toni Braxton'],
#  'url': ['/wiki/Toni_Braxton']}
# ```
# (See 1997 for an example)
#
# 3. Some songs don't have a URL. In this case, assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped:
# ```
# {'ranking': 45,
#   'song': ['Say It'],
#   'songurl': [None],
#   'titletext': '"Say It"',
#   'band_singer': ['Voices of Theory'],
#   'url': ['/wiki/Voices_of_Theory']}
# ```
# (See 1998 for an example)

# %%
"""
Function
--------
parse_year

Inputs
------
year: the year you want the singles for
ytextdixt: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    
"""
def parse_year(year, ytextdict):
    soup_year = BeautifulSoup(ytextdict[year], 'html.parser')
    tables_wikitable_year = soup_year.find_all("table", "wikitable")
    songs_years = []
    rows_years = [row_year for row_year in tables_wikitable_year[0].find_all("tr")]    
    for row_year in rows_years[1:]:
        songs_years_dict = {}        
        i = 0;
        songs_years_dict['Year'] = year
        for value_year in row_year.find_all("td"):   
            
            if i == 0:
                songs_years_dict['Ranking'] = value_year.text.strip()
            elif i == 1:
                song_title = []
                song_URL = []
                for link in value_year.findAll('a'):
                    song_title.append(link.text.strip())
                    song_URL.append(link.get('href').strip())                    
                songs_years_dict['Song'] = song_title
                songs_years_dict['Song_URL'] = song_URL
            elif i == 2:
                band_singer = []
                band_singer_URL = []
                for link in value_year.findAll('a'):
                    band_singer.append(link.text.strip())
                    band_singer_URL.append(link.get('href').strip())                    
                songs_years_dict['Band_Singer'] = band_singer
                songs_years_dict['URL'] = band_singer_URL
            i = i + 1;
        songs_years.append(songs_years_dict)
    return songs_years

# %%
yearinfo = []
iKey = 0
for iYear in range(1992, 2020):
    yearinfo.append(parse_year(iYear, yearstext))
    iKey = iKey + 1
print(yearinfo)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-478311a671bd> in <module>
#       2 iKey = 0
#       3 for iYear in range(1992, 2021):
# ----> 4     yearinfo.append(parse_year(iYear, yearstext))
#       5     iKey = iKey + 1
#       6 print(yearinfo)
#
# <ipython-input-58-cceab8498ed9> in parse_year(year, ytextdict)
#      38 """
#      39 def parse_year(year, ytextdict):
# ---> 40     soup_year = BeautifulSoup(ytextdict[year], 'html.parser')
#      41     tables_wikitable_year = soup_year.find_all("table", "wikitable")
#      42     songs_years = []
#
# KeyError: 2020

# %% [markdown]
# Save this dictionary as a json file so you do not need to run it over and over again.

# %%
#Store the dictionary and delete the variable
fd = open("yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()
del yearinfo

# %%
#Load the dictionary back to the same variable
with open("yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %%
print(yearinfo[5])
# Out:
# [{'Year': 1997, 'Ranking': '1', 'Song': ['Something About the Way You Look Tonight', 'Candle in the Wind 1997'], 'Song_URL': ['/wiki/Something_About_the_Way_You_Look_Tonight', '/wiki/Candle_in_the_Wind_1997'], 'Band_Singer': ['Elton John'], 'URL': ['/wiki/Elton_John']}, {'Year': 1997, 'Ranking': '2', 'Song': ['Foolish Games', 'You Were Meant for Me'], 'Song_URL': ['/wiki/Foolish_Games', '/wiki/You_Were_Meant_for_Me_(Jewel_song)'], 'Band_Singer': ['Jewel'], 'URL': ['/wiki/Jewel_(singer)']}, {'Year': 1997, 'Ranking': '3', 'Song': ["I'll Be Missing You"], 'Song_URL': ['/wiki/I%27ll_Be_Missing_You'], 'Band_Singer': ['Puff Daddy', 'Faith Evans', '112'], 'URL': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']}, {'Year': 1997, 'Ranking': '4', 'Song': ['Un-Break My Heart'], 'Song_URL': ['/wiki/Un-Break_My_Heart'], 'Band_Singer': ['Toni Braxton'], 'URL': ['/wiki/Toni_Braxton']}, {'Year': 1997, 'Ranking': '5', 'Song': ["Can't Nobody Hold Me Down"], 'Song_URL': ['/wiki/Can%27t_Nobody_Hold_Me_Down'], 'Band_Singer': ['Puff Daddy', 'Mase'], 'URL': ['/wiki/Sean_Combs', '/wiki/Mase']}, {'Year': 1997, 'Ranking': '6', 'Song': ['I Believe I Can Fly'], 'Song_URL': ['/wiki/I_Believe_I_Can_Fly'], 'Band_Singer': ['R. Kelly'], 'URL': ['/wiki/R._Kelly']}, {'Year': 1997, 'Ranking': '7', 'Song': ["Don't Let Go (Love)"], 'Song_URL': ['/wiki/Don%27t_Let_Go_(Love)'], 'Band_Singer': ['En Vogue'], 'URL': ['/wiki/En_Vogue']}, {'Year': 1997, 'Ranking': '8', 'Song': ['Return of the Mack'], 'Song_URL': ['/wiki/Return_of_the_Mack'], 'Band_Singer': ['Mark Morrison'], 'URL': ['/wiki/Mark_Morrison']}, {'Year': 1997, 'Ranking': '9', 'Song': ['How Do I Live'], 'Song_URL': ['/wiki/How_Do_I_Live'], 'Band_Singer': ['LeAnn Rimes'], 'URL': ['/wiki/LeAnn_Rimes']}, {'Year': 1997, 'Ranking': '10', 'Song': ['Wannabe'], 'Song_URL': ['/wiki/Wannabe'], 'Band_Singer': ['Spice Girls'], 'URL': ['/wiki/Spice_Girls']}, {'Year': 1997, 'Ranking': '11', 'Song': ['Quit Playing Games (With My Heart)'], 'Song_URL': ['/wiki/Quit_Playing_Games_(With_My_Heart)'], 'Band_Singer': ['Backstreet Boys'], 'URL': ['/wiki/Backstreet_Boys']}, {'Year': 1997, 'Ranking': '12', 'Song': ['MMMBop'], 'Song_URL': ['/wiki/MMMBop'], 'Band_Singer': ['Hanson'], 'URL': ['/wiki/Hanson_(band)']}, {'Year': 1997, 'Ranking': '13', 'Song': ['For You I Will'], 'Song_URL': ['/wiki/For_You_I_Will_(Monica_song)'], 'Band_Singer': ['Monica'], 'URL': ['/wiki/Monica_(singer)']}, {'Year': 1997, 'Ranking': '14', 'Song': ['You Make Me Wanna...'], 'Song_URL': ['/wiki/You_Make_Me_Wanna...'], 'Band_Singer': ['Usher'], 'URL': ['/wiki/Usher_(entertainer)']}, {'Year': 1997, 'Ranking': '15', 'Song': ['Bitch'], 'Song_URL': ['/wiki/Bitch_(Meredith_Brooks_song)'], 'Band_Singer': ['Meredith Brooks'], 'URL': ['/wiki/Meredith_Brooks']}, {'Year': 1997, 'Ranking': '16', 'Song': ['Nobody'], 'Song_URL': ['/wiki/Nobody_(Keith_Sweat_song)'], 'Band_Singer': ['Keith Sweat', 'Athena Cage'], 'URL': ['/wiki/Keith_Sweat', '/wiki/Athena_Cage']}, {'Year': 1997, 'Ranking': '17', 'Song': ['Semi-Charmed Life'], 'Song_URL': ['/wiki/Semi-Charmed_Life'], 'Band_Singer': ['Third Eye Blind'], 'URL': ['/wiki/Third_Eye_Blind']}, {'Year': 1997, 'Ranking': '18', 'Song': ['Barely Breathing'], 'Song_URL': ['/wiki/Barely_Breathing'], 'Band_Singer': ['Duncan Sheik'], 'URL': ['/wiki/Duncan_Sheik']}, {'Year': 1997, 'Ranking': '19', 'Song': ["Hard to Say I'm Sorry"], 'Song_URL': ['/wiki/Hard_to_Say_I%27m_Sorry'], 'Band_Singer': ['Az Yet', 'Peter Cetera'], 'URL': ['/wiki/Az_Yet', '/wiki/Peter_Cetera']}, {'Year': 1997, 'Ranking': '20', 'Song': ['Mo Money Mo Problems'], 'Song_URL': ['/wiki/Mo_Money_Mo_Problems'], 'Band_Singer': ['The Notorious B.I.G.', 'Puff Daddy', 'Mase'], 'URL': ['/wiki/The_Notorious_B.I.G.', '/wiki/Sean_Combs', '/wiki/Mase']}, {'Year': 1997, 'Ranking': '21', 'Song': ['The Freshmen'], 'Song_URL': ['/wiki/The_Freshmen_(song)'], 'Band_Singer': ['The Verve Pipe'], 'URL': ['/wiki/The_Verve_Pipe']}, {'Year': 1997, 'Ranking': '22', 'Song': ['I Want You'], ...

# %% [markdown]
# ## Q2: Construct a year-song-singer dataframe
# #### [20 points]

# %% [markdown]
# Now, let's construct a dataframe from the dictionary created in the previous section `yearinfo`.
# Name this dataframe `flatframe`.
#
# Keep in mind, in the data structure we have so far, a given key can have a list of values with multiple entries. Also, our data is grouped by year. So we need a way to flatten this data into a format that will create a useful DataFrame.
#
# An easy way to do this is to use the pandas `concat` function.
#
# Your final dataframe `flatframe` should look something like this:
# ![flatframexample](https://drive.google.com/uc?export=view&id=12hlpB-zRGJh6JYCTcMoTzumKSyXgfoiY)

# %%
flatframe = pd.DataFrame(yearinfo)
print(flatframe)
# Out:
#                                                    0   \
# 0   {'Year': 1992, 'Ranking': '1', 'Song': ['End o...
# 1   {'Year': 1993, 'Ranking': '1', 'Song': ['I Wil...
# 2   {'Year': 1994, 'Ranking': '1', 'Song': ['The S...
# 3   {'Year': 1995, 'Ranking': '1', 'Song': ['Gangs...
# 4   {'Year': 1996, 'Ranking': '1', 'Song': ['Macar...
# 5   {'Year': 1997, 'Ranking': '1', 'Song': ['Somet...
# 6   {'Year': 1998, 'Ranking': '1', 'Song': ['Too C...
# 7   {'Year': 1999, 'Ranking': '1', 'Song': ['Belie...
# 8   {'Year': 2000, 'Ranking': '1', 'Song': ['Breat...
# 9   {'Year': 2001, 'Ranking': '1', 'Song': ['Hangi...
# 10  {'Year': 2002, 'Ranking': '1', 'Song': ['How Y...
# 11  {'Year': 2003, 'Ranking': '1', 'Song': ['In da...
# 12  {'Year': 2004, 'Ranking': '1', 'Song': ['Yeah!...
# 13  {'Year': 2005, 'Ranking': '1', 'Song': ['We Be...
# 14  {'Year': 2006, 'Ranking': '1', 'Song': ['Bad D...
# 15  {'Year': 2007, 'Ranking': '1', 'Song': ['Irrep...
# 16  {'Year': 2008, 'Ranking': '1', 'Song': ['Low']...
# 17  {'Year': 2009, 'Ranking': '1', 'Song': ['Boom ...
# 18  {'Year': 2010, 'Ranking': '1', 'Song': ['Tik T...
# 19  {'Year': 2011, 'Ranking': '1', 'Song': ['Rolli...
# 20  {'Year': 2012, 'Ranking': '1', 'Song': ['Someb...
# 21  {'Year': 2013, 'Ranking': '1', 'Song': ['Thrif...
# 22  {'Year': 2014, 'Ranking': '1', 'Song': ['Happy...
# 23  {'Year': 2015, 'Ranking': '1', 'Song': ['Uptow...
# 24  {'Year': 2016, 'Ranking': '1', 'Song': ['Love ...
# 25  {'Year': 2017, 'Ranking': '1', 'Song': ['Shape...
# 26  {'Year': 2018, 'Ranking': '1', 'Song': ['God's...
# 27  {'Year': 2019, 'Ranking': '1', 'Song': ['Old T...
#
#                                                    1   \
# 0   {'Year': 1992, 'Ranking': '2', 'Song': ['Baby ...
# 1   {'Year': 1993, 'Ranking': '2', 'Song': ['Whoom...
# 2   {'Year': 1994, 'Ranking': '2', 'Song': ['I Swe...
# 3   {'Year': 1995, 'Ranking': '2', 'Song': ['Water...
# 4   {'Year': 1996, 'Ranking': '2', 'Song': ['One S...
# 5   {'Year': 1997, 'Ranking': '2', 'Song': ['Fooli...
# 6   {'Year': 1998, 'Ranking': '2', 'Song': ['The B...
# 7   {'Year': 1999, 'Ranking': '2', 'Song': ['No Sc...
# 8   {'Year': 2000, 'Ranking': '2', 'Song': ['Smoot...
# 9   {'Year': 2001, 'Ranking': '2', 'Song': ['Falli...
# 10  {'Year': 2002, 'Ranking': '2', 'Song': ['Fooli...
# 11  {'Year': 2003, 'Ranking': '2', 'Song': ['Ignit...
# 12  {'Year': 2004, 'Ranking': '2', 'Song': ['Burn'...
# 13  {'Year': 2005, 'Ranking': '2', 'Song': ['Holla...
# 14  {'Year': 2006, 'Ranking': '2', 'Song': ['Tempe...
# 15  {'Year': 2007, 'Ranking': '2', 'Song': ['Umbre...
# 16  {'Year': 2008, 'Ranking': '2', 'Song': ['Bleed...
# 17  {'Year': 2009, 'Ranking': '2', 'Song': ['Poker...
# 18  {'Year': 2010, 'Ranking': '2', 'Song': ['Need ...
# 19  {'Year': 2011, 'Ranking': '2', 'Song': ['Party...
# 20  {'Year': 2012, 'Ranking': '2', 'Song': ['Call ...
# 21  {'Year': 2013, 'Ranking': '2', 'Song': ['Blurr...
# 22  {'Year': 2014, 'Ranking': '2', 'Song': ['Dark ...
# 23  {'Year': 2015, 'Ranking': '2', 'Song': ['Think...
# 24  {'Year': 2016, 'Ranking': '2', 'Song': ['Sorry...
# 25  {'Year': 2017, 'Ranking': '2', 'Song': ['Despa...
# 26  {'Year': 2018, 'Ranking': '2', 'Song': ['Perfe...
# 27  {'Year': 2019, 'Ranking': '2', 'Song': ['Sunfl...
#
#                                                    2   \
# 0   {'Year': 1992, 'Ranking': '3', 'Song': ['Jump'...
# 1   {'Year': 1993, 'Ranking': '3', 'Song': ['Can't...
# 2   {'Year': 1994, 'Ranking': '3', 'Song': ['I'll ...
# 3   {'Year': 1995, 'Ranking': '3', 'Song': ['Creep...
# 4   {'Year': 1996, 'Ranking': '3', 'Song': ['Becau...
# 5   {'Year': 1997, 'Ranking': '3', 'Song': ['I'll ...
# 6   {'Year': 1998, 'Ranking': '3', 'Song': ['You'r...
# 7   {'Year': 1999, 'Ranking': '3', 'Song': ['Angel...
# 8   {'Year': 2000, 'Ranking': '3', 'Song': ['Maria...
# 9   {'Year': 2001, 'Ranking': '3', 'Song': ['All f...
# 10  {'Year': 2002, 'Ranking': '3', 'Song': ['Hot i...
# 11  {'Year': 2003, 'Ranking': '3', 'Song': ['Get B...
# 12  {'Year': 2004, 'Ranking': '3', 'Song': ['If I ...
# 13  {'Year': 2005, 'Ranking': '3', 'Song': ['Let M...
# 14  {'Year': 2006, 'Ranking': '3', 'Song': ['Promi...
# 15  {'Year': 2007, 'Ranking': '3', 'Song': ['The S...
# 16  {'Year': 2008, 'Ranking': '3', 'Song': ['No On...
# 17  {'Year': 2009, 'Ranking': '3', 'Song': ['Just ...
# 18  {'Year': 2010, 'Ranking': '3', 'Song': ['Hey, ...
# 19  {'Year': 2011, 'Ranking': '3', 'Song': ['Firew...
# 20  {'Year': 2012, 'Ranking': '3', 'Song': ['We Ar...
# 21  {'Year': 2013, 'Ranking': '3', 'Song': ['Radio...
# 22  {'Year': 2014, 'Ranking': '3', 'Song': ['All o...
# 23  {'Year': 2015, 'Ranking': '3', 'Song': ['See Y...
# 24  {'Year': 2016, 'Ranking': '3', 'Song': ['One D...
# 25  {'Year': 2017, 'Ranking': '3', 'Song': ['That'...
# 26  {'Year': 2018, 'Ranking': '3', 'Song': ['Meant...
# 27  {'Year': 2019, 'Ranking': '3', 'Song': ['Witho...
#
#                                                    3   \
# 0   {'Year': 1992, 'Ranking': '4', 'Song': ['Save ...
# 1   {'Year': 1993, 'Ranking': '4', 'Song': ['That'...
# 2   {'Year': 1994, 'Ranking': '4', 'Song': ['The P...
# 3   {'Year': 1995, 'Ranking': '4', 'Song': ['Kiss ...
# 4   {'Year': 1996, 'Ranking': '4', 'Song': ['Nobod...
# 5   {'Year': 1997, 'Ranking': '4', 'Song': ['Un-Br...
# 6   {'Year': 1998, 'Ranking': '4', 'Song': ['Truly...
# 7   {'Year': 1999, 'Ranking': '4', 'Song': ['Heart...
# 8   {'Year': 2000, 'Ranking': '4', 'Song': ['I Wan...
# 9   {'Year': 2001, 'Ranking': '4', 'Song': ['Drops...
# 10  {'Year': 2002, 'Ranking': '4', 'Song': ['Dilem...
# 11  {'Year': 2003, 'Ranking': '4', 'Song': ['Crazy...
# 12  {'Year': 2004, 'Ranking': '4', 'Song': ['This ...
# 13  {'Year': 2005, 'Ranking': '4', 'Song': ['Since...
# 14  {'Year': 2006, 'Ranking': '4', 'Song': ['You'r...
# 15  {'Year': 2007, 'Ranking': '4', 'Song': ['Big G...
# 16  {'Year': 2008, 'Ranking': '4', 'Song': ['Lolli...
# 17  {'Year': 2009, 'Ranking': '4', 'Song': ['I Got...
# 18  {'Year': 2010, 'Ranking': '4', 'Song': ['Calif...
# 19  {'Year': 2011, 'Ranking': '4', 'Song': ['E.T.'...
# 20  {'Year': 2012, 'Ranking': '4', 'Song': ['Payph...
# 21  {'Year': 2013, 'Ranking': '4', 'Song': ['Harle...
# 22  {'Year': 2014, 'Ranking': '4', 'Song': ['Fancy...
# 23  {'Year': 2015, 'Ranking': '4', 'Song': ['Trap ...
# 24  {'Year': 2016, 'Ranking': '4', 'Song': ['Work'...
# 25  {'Year': 2017, 'Ranking': '4', 'Song': ['Humbl...
# 26  {'Year': 2018, 'Ranking': '4', 'Song': ['Havan...
# 27  {'Year': 2019, 'Ranking': '4', 'Song': ['Bad G...
#
#                                                    4   \
# 0   {'Year': 1992, 'Ranking': '5', 'Song': ['Baby-...
# 1   {'Year': 1993, 'Ranking': '5', 'Song': ['Freak...
# 2   {'Year': 1994, 'Ranking': '5', 'Song': ['Hero'...
# 3   {'Year': 1995, 'Ranking': '5', 'Song': ['On Be...
# 4   {'Year': 1996, 'Ranking': '5', 'Song': ['Alway...
# 5   {'Year': 1997, 'Ranking': '5', 'Song': ['Can't...
# 6   {'Year': 1998, 'Ranking': '5', 'Song': ['How D...
# 7   {'Year': 1999, 'Ranking': '5', 'Song': ['...Ba...
# 8   {'Year': 2000, 'Ranking': '5', 'Song': ['Every...
# 9   {'Year': 2001, 'Ranking': '5', 'Song': ['I'm R...
# 10  {'Year': 2002, 'Ranking': '5', 'Song': ['Where...
# 11  {'Year': 2003, 'Ranking': '5', 'Song': ['When ...
# 12  {'Year': 2004, 'Ranking': '5', 'Song': ['The W...
# 13  {'Year': 2005, 'Ranking': '5', 'Song': ['1, 2 ...
# 14  {'Year': 2006, 'Ranking': '5', 'Song': ['Hips ...
# 15  {'Year': 2007, 'Ranking': '5', 'Song': ['Buy U...
# 16  {'Year': 2008, 'Ranking': '5', 'Song': ['Apolo...
# 17  {'Year': 2009, 'Ranking': '5', 'Song': ['Love ...
# 18  {'Year': 2010, 'Ranking': '5', 'Song': ['OMG']...
# 19  {'Year': 2011, 'Ranking': '5', 'Song': ['Give ...
# 20  {'Year': 2012, 'Ranking': '5', 'Song': ['Light...
# 21  {'Year': 2013, 'Ranking': '5', 'Song': ['Can't...
# 22  {'Year': 2014, 'Ranking': '5', 'Song': ['Count...
# 23  {'Year': 2015, 'Ranking': '5', 'Song': ['Sugar...
# 24  {'Year': 2016, 'Ranking': '5', 'Song': ['Stres...
# 25  {'Year': 2017, 'Ranking': '5', 'Song': ['Somet...
# 26  {'Year': 2018, 'Ranking': '5', 'Song': ['Rocks...
# 27  {'Year': 2019, 'Ranking': '5', 'Song': ['Wow']...
#
#                                                    5   \
# 0   {'Year': 1992, 'Ranking': '6', 'Song': ['Tears...
# 1   {'Year': 1993, 'Ranking': '6', 'Song': ['Weak'...
# 2   {'Year': 1994, 'Ranking': '6', 'Song': ['Stay ...
# 3   {'Year': 1995, 'Ranking': '6', 'Song': ['Anoth...
# 4   {'Year': 1996, 'Ranking': '6', 'Song': ['Give ...
# 5   {'Year': 1997, 'Ranking': '6', 'Song': ['I Bel...
# 6   {'Year': 1998, 'Ranking': '6', 'Song': ['Toget...
# 7   {'Year': 1999, 'Ranking': '6', 'Song': ['Kiss ...
# 8   {'Year': 2000, 'Ranking': '6', 'Song': ['Say M...
# 9   {'Year': 2001, 'Ranking': '6', 'Song': ['If Yo...
# 10  {'Year': 2002, 'Ranking': '6', 'Song': ['A Tho...
# 11  {'Year': 2003, 'Ranking': '6', 'Song': ['Unwel...
# 12  {'Year': 2004, 'Ranking': '6', 'Song': ['The R...
# 13  {'Year': 2005, 'Ranking': '6', 'Song': ['Gold ...
# 14  {'Year': 2006, 'Ranking': '6', 'Song': ['Unwri...
# 15  {'Year': 2007, 'Ranking': '6', 'Song': ['Befor...
# 16  {'Year': 2008, 'Ranking': '6', 'Song': ['No Ai...
# 17  {'Year': 2009, 'Ranking': '6', 'Song': ['Right...
# 18  {'Year': 2010, 'Ranking': '6', 'Song': ['Airpl...
# 19  {'Year': 2011, 'Ranking': '6', 'Song': ['Grena...
# 20  {'Year': 2012, 'Ranking': '6', 'Song': ['Glad ...
# 21  {'Year': 2013, 'Ranking': '6', 'Song': ['Mirro...
# 22  {'Year': 2014, 'Ranking': '6', 'Song': ['Talk ...
# 23  {'Year': 2015, 'Ranking': '6', 'Song': ['Shut ...
# 24  {'Year': 2016, 'Ranking': '6', 'Song': ['Panda...
# 25  {'Year': 2017, 'Ranking': '6', 'Song': ['Bad a...
# 26  {'Year': 2018, 'Ranking': '6', 'Song': ['Psych...
# 27  {'Year': 2019, 'Ranking': '6', 'Song': ['Happi...
#
#                                                    6   \
# 0   {'Year': 1992, 'Ranking': '7', 'Song': ['My Lo...
# 1   {'Year': 1993, 'Ranking': '7', 'Song': ['If I ...
# 2   {'Year': 1994, 'Ranking': '7', 'Song': ['Breat...
# 3   {'Year': 1995, 'Ranking': '7', 'Song': ['Fanta...
# 4   {'Year': 1996, 'Ranking': '7', 'Song': ['Tha C...
# 5   {'Year': 1997, 'Ranking': '7', 'Song': ['Don't...
# 6   {'Year': 1998, 'Ranking': '7', 'Song': ['All M...
# 7   {'Year': 1999, 'Ranking': '7', 'Song': ['Genie...
# 8   {'Year': 2000, 'Ranking': '7', 'Song': ['I Kne...
# 9   {'Year': 2001, 'Ranking': '7', 'Song': ['Let M...
# 25  {'Year': 2017, 'Ranking': '8', 'Song': ['Body ...
# 26  {'Year': 2018, 'Ranking': '8', 'Song': ['The M...
# 27  {'Year': 2019, 'Ranking': '8', 'Song': ['Talk'...
#
#                                                    8   \
# 0   {'Year': 1992, 'Ranking': '9', 'Song': ['All 4...
# 1   {'Year': 1993, 'Ranking': '9', 'Song': ['Rump ...
# 2   {'Year': 1994, 'Ranking': '9', 'Song': ['All T...
# 3   {'Year': 1995, 'Ranking': '9', 'Song': ['Don't...
# 4   {'Year': 1996, 'Ranking': '9', 'Song': ['You'r...
# 5   {'Year': 1997, 'Ranking': '9', 'Song': ['How D...
# 6   {'Year': 1998, 'Ranking': '9', 'Song': ['Nice ...
# 7   {'Year': 1999, 'Ranking': '9', 'Song': ['Nobod...
# 8   {'Year': 2000, 'Ranking': '9', 'Song': ['Bent'...
# 9   {'Year': 2001, 'Ranking': '9', 'Song': ['Again...
# 10  {'Year': 2002, 'Ranking': '9', 'Song': ['U Got...
# 11  {'Year': 2003, 'Ranking': '9', 'Song': ['Pictu...
# 12  {'Year': 2004, 'Ranking': '9', 'Song': ['Goodi...
# 13  {'Year': 2005, 'Ranking': '9', 'Song': ['Don't...
# 14  {'Year': 2006, 'Ranking': '9', 'Song': ['SexyB...
# 15  {'Year': 2007, 'Ranking': '9', 'Song': ['Say I...
# 16  {'Year': 2008, 'Ranking': '9', 'Song': ['With ...
# 17  {'Year': 2009, 'Ranking': '9', 'Song': ['Heart...
# 18  {'Year': 2010, 'Ranking': '9', 'Song': ['Dynam...
# 19  {'Year': 2011, 'Ranking': '9', 'Song': ['Moves...
# 20  {'Year': 2012, 'Ranking': '9', 'Song': ['Stars...
# 21  {'Year': 2013, 'Ranking': '9', 'Song': ['Cruis...
# 22  {'Year': 2014, 'Ranking': '9', 'Song': ['Probl...
# 23  {'Year': 2015, 'Ranking': '9', 'Song': ['Earne...
# 24  {'Year': 2016, 'Ranking': '9', 'Song': ['Can't...
# 25  {'Year': 2017, 'Ranking': '9', 'Song': ['Belie...
# 26  {'Year': 2018, 'Ranking': '9', 'Song': ['In My...
# 27  {'Year': 2019, 'Ranking': '9', 'Song': ['Sicko...
#
#                                                    9   ...  \
# 0   {'Year': 1992, 'Ranking': '10', 'Song': ['Just...  ...
# 1   {'Year': 1993, 'Ranking': '10', 'Song': ['Info...  ...
# 2   {'Year': 1994, 'Ranking': '10', 'Song': ['Don'...  ...
# 3   {'Year': 1995, 'Ranking': '10', 'Song': ['This...  ...
# 4   {'Year': 1996, 'Ranking': '10', 'Song': ['Twis...  ...
# 5   {'Year': 1997, 'Ranking': '10', 'Song': ['Wann...  ...
# 6   {'Year': 1998, 'Ranking': '10', 'Song': ['I Do...  ...
# 7   {'Year': 1999, 'Ranking': '10', 'Song': ['Livi...  ...
# 8   {'Year': 2000, 'Ranking': '10', 'Song': ['He W...  ...
# 9   {'Year': 2001, 'Ranking': '10', 'Song': ['Inde...  ...
# 10  {'Year': 2002, 'Ranking': '10', 'Song': ['Blur...  ...
# 11  {'Year': 2003, 'Ranking': '10', 'Song': ['Brin...  ...
# 12  {'Year': 2004, 'Ranking': '10', 'Song': ['Lean...  ...
# 13  {'Year': 2005, 'Ranking': '10', 'Song': ['Behi...  ...
# 14  {'Year': 2006, 'Ranking': '10', 'Song': ['Chec...  ...
# 15  {'Year': 2007, 'Ranking': '10', 'Song': ['Glam...  ...
# 16  {'Year': 2008, 'Ranking': '10', 'Song': ['Fore...  ...
# 17  {'Year': 2009, 'Ranking': '10', 'Song': ['Give...  ...
# 18  {'Year': 2010, 'Ranking': '10', 'Song': ['Brea...  ...
# 19  {'Year': 2011, 'Ranking': '10', 'Song': ['Just...  ...
# 20  {'Year': 2012, 'Ranking': '10', 'Song': ['What...  ...
# 21  {'Year': 2013, 'Ranking': '10', 'Song': ['Roar...  ...
# 22  {'Year': 2014, 'Ranking': '10', 'Song': ['Stay...  ...
# 23  {'Year': 2015, 'Ranking': '10', 'Song': ['The ...  ...
# 24  {'Year': 2016, 'Ranking': '10', 'Song': ['Clos...  ...
# 25  {'Year': 2017, 'Ranking': '10', 'Song': ['Cong...  ...
# 26  {'Year': 2018, 'Ranking': '10', 'Song': ['Girl...  ...
# 27  {'Year': 2019, 'Ranking': '10', 'Song': ['Suck...  ...
#
#                                                    90  \
# 0   {'Year': 1992, 'Ranking': '91', 'Song': ['That...
# 1   {'Year': 1993, 'Ranking': '91', 'Song': ['Brea...
# 2   {'Year': 1994, 'Ranking': '91', 'Song': ['Alwa...
# 3   {'Year': 1995, 'Ranking': '91', 'Song': ['I Li...
# 4   {'Year': 1996, 'Ranking': '91', 'Song': ['Po P...
# 5   {'Year': 1997, 'Ranking': '91', 'Song': [], 'S...
# 6   {'Year': 1998, 'Ranking': '91', 'Song': [], 'S...
# 7   {'Year': 1999, 'Ranking': '91', 'Song': ['Take...
# 8   {'Year': 2000, 'Ranking': '91', 'Song': ['I Li...
# 9   {'Year': 2001, 'Ranking': '91', 'Song': ['You ...
# 10  {'Year': 2002, 'Ranking': '91', 'Song': ['A Ne...
# 11  {'Year': 2003, 'Ranking': '91', 'Song': ['No S...
# 12  {'Year': 2004, 'Ranking': '91', 'Song': ['Chan...
# 13  {'Year': 2005, 'Ranking': '91', 'Song': ['O'],...
# 14  {'Year': 2006, 'Ranking': '91', 'Song': ['Hung...
# 15  {'Year': 2007, 'Ranking': '91', 'Song': ['Snow...
# 16  {'Year': 2008, 'Ranking': '91', 'Song': ['Mrs....
# 17  {'Year': 2009, 'Ranking': '91', 'Song': ['I Do...
# 18  {'Year': 2010, 'Ranking': '91', 'Song': ['The ...
# 19  {'Year': 2011, 'Ranking': '91', 'Song': ['Plea...
# 20  {'Year': 2012, 'Ranking': '91', 'Song': ['It's...
# 21  {'Year': 2013, 'Ranking': '91', 'Song': ['Buga...
# 22  {'Year': 2014, 'Ranking': '91', 'Song': ['Beac...
# 23  {'Year': 2015, 'Ranking': '91', 'Song': ['Hear...
# 24  {'Year': 2016, 'Ranking': '91', 'Song': ['Cut ...
# 25  {'Year': 2017, 'Ranking': '91', 'Song': ['No P...
# 1   {'Year': 1993, 'Ranking': '95', 'Song': ['Hey ...
# 2   {'Year': 1994, 'Ranking': '95', 'Song': ['I'll...
# 3   {'Year': 1995, 'Ranking': '95', 'Song': ['I'll...
# 4   {'Year': 1996, 'Ranking': '95', 'Song': ['Back...
# 5   {'Year': 1997, 'Ranking': '95', 'Song': ['When...
# 6   {'Year': 1998, 'Ranking': '95', 'Song': ['A Ro...
# 7   {'Year': 1999, 'Ranking': '95', 'Song': ['Sati...
# 8   {'Year': 2000, 'Ranking': '95', 'Song': ['Cowb...
# 9   {'Year': 2001, 'Ranking': '95', 'Song': ['E.I....
# 10  {'Year': 2002, 'Ranking': '95', 'Song': ['Hand...
# 11  {'Year': 2003, 'Ranking': '95', 'Song': ['I Wa...
# 12  {'Year': 2004, 'Ranking': '95', 'Song': ['Hey ...
# 13  {'Year': 2005, 'Ranking': '95', 'Song': ['I'm ...
# 14  {'Year': 2006, 'Ranking': '95', 'Song': ['Why ...
# 15  {'Year': 2007, 'Ranking': '95', 'Song': ['Rock...
# 16  {'Year': 2008, 'Ranking': '95', 'Song': ['Feel...
# 17  {'Year': 2009, 'Ranking': '95', 'Song': ['Alre...
# 18  {'Year': 2010, 'Ranking': '95', 'Song': ['King...
# 19  {'Year': 2011, 'Ranking': '95', 'Song': ['She ...
# 20  {'Year': 2012, 'Ranking': '95', 'Song': ['Hard...
# 21  {'Year': 2013, 'Ranking': '95', 'Song': ['#tha...
# 22  {'Year': 2014, 'Ranking': '95', 'Song': ['Part...
# 23  {'Year': 2015, 'Ranking': '95', 'Song': ['Wave...
# 24  {'Year': 2016, 'Ranking': '95', 'Song': ['Adve...
# 25  {'Year': 2017, 'Ranking': '95', 'Song': ['Ever...
# 26  {'Year': 2018, 'Ranking': '95', 'Song': ['Merc...
# 27  {'Year': 2019, 'Ranking': '95', 'Song': ['Beau...
#
#                                                    95  \
# 0   {'Year': 1992, 'Ranking': '96', 'Song': ['I Wi...
# 1   {'Year': 1993, 'Ranking': '96', 'Song': ['If I...
# 2   {'Year': 1994, 'Ranking': '96', 'Song': ['Alwa...
# 3   {'Year': 1995, 'Ranking': '96', 'Song': ['I Mi...
# 4   {'Year': 1996, 'Ranking': '96', 'Song': ['I Go...
# 5   {'Year': 1997, 'Ranking': '96', 'Song': ['Let ...
# 6   {'Year': 1998, 'Ranking': '96', 'Song': ['4 Se...
# 7   {'Year': 1999, 'Ranking': '96', 'Song': ['Bett...
# 8   {'Year': 2000, 'Ranking': '96', 'Song': ['I Do...
# 9   {'Year': 2001, 'Ranking': '96', 'Song': ['Be L...
# 10  {'Year': 2002, 'Ranking': '96', 'Song': ['Sk8e...
# 11  {'Year': 2003, 'Ranking': '96', 'Song': ['Like...
# 12  {'Year': 2004, 'Ranking': '96', 'Song': ['Over...
# 13  {'Year': 2005, 'Ranking': '96', 'Song': ['Char...
# 14  {'Year': 2006, 'Ranking': '96', 'Song': ['Stup...
# 15  {'Year': 2007, 'Ranking': '96', 'Song': ['Love...
# 16  {'Year': 2008, 'Ranking': '96', 'Song': ['The ...
# 21  {'Year': 2013, 'Ranking': '99', 'Song': ['I'm ...
# 22  {'Year': 2014, 'Ranking': '99', 'Song': ['Some...
# 23  {'Year': 2015, 'Ranking': '99', 'Song': ['Back...
# 24  {'Year': 2016, 'Ranking': '99', 'Song': ['See ...
# 25  {'Year': 2017, 'Ranking': '99', 'Song': ['Look...
# 26  {'Year': 2018, 'Ranking': '99', 'Song': ['Mi G...
# 27  {'Year': 2019, 'Ranking': '99', 'Song': ['Walk...
#
#                                                    99
# 0   {'Year': 1992, 'Ranking': '100', 'Song': ['I C...
# 1   {'Year': 1993, 'Ranking': '100', 'Song': ['Two...
# 2   {'Year': 1994, 'Ranking': '100', 'Song': ['I W...
# 3   {'Year': 1995, 'Ranking': '100', 'Song': ['Can...
# 4   {'Year': 1996, 'Ranking': '100', 'Song': ['Don...
# 5   {'Year': 1997, 'Ranking': '100', 'Song': ['Let...
# 6   {'Year': 1998, 'Ranking': '100', 'Song': ['Wes...
# 7   {'Year': 1999, 'Ranking': '100', 'Song': ['(Go...
# 8   {'Year': 2000, 'Ranking': '100', 'Song': ['Sha...
# 9   {'Year': 2001, 'Ranking': '100', 'Song': ['Hem...
# 10  {'Year': 2002, 'Ranking': '100', 'Song': ['I D...
# 11  {'Year': 2003, 'Ranking': '100', 'Song': ['Say...
# 12  {'Year': 2004, 'Ranking': '100', 'Song': ['I G...
# 13  {'Year': 2005, 'Ranking': '100', 'Song': ['Giv...
# 14  {'Year': 2006, 'Ranking': '100', 'Song': ['For...
# 15  {'Year': 2007, 'Ranking': '100', 'Song': ['Sam...
# 16  {'Year': 2008, 'Ranking': '100', 'Song': ['She...
# 17  {'Year': 2009, 'Ranking': '100', 'Song': ['Nev...
# 18  {'Year': 2010, 'Ranking': '100', 'Song': ['Lov...
# 19  {'Year': 2011, 'Ranking': '100', 'Song': ['My ...
# 20  {'Year': 2012, 'Ranking': '100', 'Song': ['Bur...
# 21  {'Year': 2013, 'Ranking': '100', 'Song': ['Sti...
# 22  {'Year': 2014, 'Ranking': '100', 'Song': ['Ado...
# 23  {'Year': 2015, 'Ranking': '100', 'Song': ['How...
# 24  {'Year': 2016, 'Ranking': '100', 'Song': ['Per...
# 25  {'Year': 2017, 'Ranking': '100', 'Song': ['The...
# 26  {'Year': 2018, 'Ranking': '100', 'Song': ['Bel...
# 27  {'Year': 2019, 'Ranking': '100', 'Song': ['Rob...
#
# [28 rows x 100 columns]

# %%
pd.set_option('display.max_rows', 1000)
#yearinfo - List of list of dicts
#yearinfo[1] - List of dics
flatframe = pd.DataFrame(yearinfo[0])
for iYear in range(len(yearinfo) - 1):
    flatframe1 = pd.DataFrame(yearinfo[iYear])
    flatframe = pd.concat([flatframe, flatframe1], ignore_index=True)
#flatframe.reset_index(drop=True)
print(flatframe)
#flatframe
#flatframe.tail(150)
# Out:
#       Year Ranking                      Song  \
# 0     1992       1         [End of the Road]
# 1     1992       2           [Baby Got Back]
# 2     1992       3                    [Jump]
# 3     1992       4  [Save the Best for Last]
# 4     1992       5          [Baby-Baby-Baby]
# ...    ...     ...                       ...
# 2795  2018      96         [One Number Away]
# 2796  2018      97              [Powerglide]
# 2797  2018      98                   [IDGAF]
# 2798  2018      99                [Mi Gente]
# 2799  2018     100                [Believer]
#
#                                                Song_URL  \
# 0            [/wiki/End_of_the_Road_(Boyz_II_Men_song)]
# 1                                 [/wiki/Baby_Got_Back]
# 2                        [/wiki/Jump_(Kris_Kross_song)]
# 3                        [/wiki/Save_the_Best_for_Last]
# 4                                [/wiki/Baby-Baby-Baby]
# ...                                                 ...
# 2795                            [/wiki/One_Number_Away]
# 2796                          [/wiki/Powerglide_(song)]
# 2797                               [/wiki/IDGAF_(song)]
# 2798  [/wiki/Mi_Gente_(J_Balvin_and_Willy_William_so...
# 2799            [/wiki/Believer_(Imagine_Dragons_song)]
#
#                              Band_Singer  \
# 0                          [Boyz II Men]
# 1                        [Sir Mix-a-Lot]
# 2                           [Kris Kross]
# 3                     [Vanessa Williams]
# 4                                  [TLC]
# ...                                  ...
# 2795                        [Luke Combs]
# 2796             [Rae Sremmurd, Juicy J]
# 2797                          [Dua Lipa]
# 2798  [J Balvin, Willy William, Beyoncé]
# 2799                   [Imagine Dragons]
#
#                                                     URL
# 0                                   [/wiki/Boyz_II_Men]
# 1                                 [/wiki/Sir_Mix-a-Lot]
# 2                                    [/wiki/Kris_Kross]
# 3                           [/wiki/Vanessa_L._Williams]
# 4                                    [/wiki/TLC_(band)]
# ...                                                 ...
# 2795                                 [/wiki/Luke_Combs]
# 2796                [/wiki/Rae_Sremmurd, /wiki/Juicy_J]
# 2797                                   [/wiki/Dua_Lipa]
# 2798  [/wiki/J_Balvin, /wiki/Willy_William, /wiki/Be...
# 2799                            [/wiki/Imagine_Dragons]
#
# [2800 rows x 6 columns]

# %% [markdown]
# Check your dataframes data types and convert them to the correct data types if needed.

# %%
flatframe.dtypes
# Out:
# Year            int64
# Ranking        object
# Song           object
# Song_URL       object
# Band_Singer    object
# URL            object
# dtype: object

# %%
flatframe.head()
# Out:
#    Year Ranking                      Song  \
# 0  1992       1         [End of the Road]
# 1  1992       2           [Baby Got Back]
# 2  1992       3                    [Jump]
# 3  1992       4  [Save the Best for Last]
# 4  1992       5          [Baby-Baby-Baby]
#
#                                      Song_URL         Band_Singer  \
# 0  [/wiki/End_of_the_Road_(Boyz_II_Men_song)]       [Boyz II Men]
# 1                       [/wiki/Baby_Got_Back]     [Sir Mix-a-Lot]
# 2              [/wiki/Jump_(Kris_Kross_song)]        [Kris Kross]
# 3              [/wiki/Save_the_Best_for_Last]  [Vanessa Williams]
# 4                      [/wiki/Baby-Baby-Baby]               [TLC]
#
#                            URL
# 0          [/wiki/Boyz_II_Men]
# 1        [/wiki/Sir_Mix-a-Lot]
# 2           [/wiki/Kris_Kross]
# 3  [/wiki/Vanessa_L._Williams]
# 4           [/wiki/TLC_(band)]

# %% [markdown]
# We use this dataframe in Homework 2, so store this dataframe so you won't need to run this again!
#
# The easiest way is to pickle it using to_pickle:

# %%
#Store the dataframe and delete the variable
flatframe.to_pickle('flatframedf')
del flatframe

# %%
#Loading in the dataframe
flatframe = pd.read_pickle('flatframedf')
flatframe.head()
# Out:
#    Year Ranking                      Song  \
# 0  1992       1         [End of the Road]
# 1  1992       2           [Baby Got Back]
# 2  1992       3                    [Jump]
# 3  1992       4  [Save the Best for Last]
# 4  1992       5          [Baby-Baby-Baby]
#
#                                      Song_URL         Band_Singer  \
# 0  [/wiki/End_of_the_Road_(Boyz_II_Men_song)]       [Boyz II Men]
# 1                       [/wiki/Baby_Got_Back]     [Sir Mix-a-Lot]
# 2              [/wiki/Jump_(Kris_Kross_song)]        [Kris Kross]
# 3              [/wiki/Save_the_Best_for_Last]  [Vanessa Williams]
# 4                      [/wiki/Baby-Baby-Baby]               [TLC]
#
#                            URL
# 0          [/wiki/Boyz_II_Men]
# 1        [/wiki/Sir_Mix-a-Lot]
# 2           [/wiki/Kris_Kross]
# 3  [/wiki/Vanessa_L._Williams]
# 4           [/wiki/TLC_(band)]

# %% [markdown]
# ## Q3: Scrape and Parse Wikipedia for Information about Artists and Bands
# #### [25 points]

# %% [markdown]
# Now, we need to fetch information about the singers or bands for all the songs in a list of years.

# %% [markdown]
# ### 3.1 Scrape the artist's Wikipedia webpages

# %% [markdown]
# Since we have hundreds of artists webpages to scrape, we have created a function which implements caching in order to speed up this process.
#
# The cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Remember that this function is designed to be used in a loop over years, and then a loop over songs per year. Since network requests are relatively slow, if we have already requested for a singer or band's wikipedia page, caching the results is a smart thing to do.
#
#
#
# Notice that we have wrapped the call in _an exception block_. If the request gets an HTTP code different from 200, the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.

# %%
urlcache={}
def get_page(url):
    url = url[0]
    print(url)
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)
            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# Before we apply our function to the dataframe, let us sort `flatframe` by year. This will ensure that we will hit the cache most as singers who show up repeatedly in the rankings will have their information already pulled.

# %%
flatframe=flatframe.sort_values('Year')
flatframe.head()
# Out:
#     Year Ranking                        Song  \
# 0   1992       1           [End of the Road]
# 99  1992     100  [I Can't Make You Love Me]
# 1   1992       2             [Baby Got Back]
# 2   1992       3                      [Jump]
# 3   1992       4    [Save the Best for Last]
#
#                                       Song_URL         Band_Singer  \
# 0   [/wiki/End_of_the_Road_(Boyz_II_Men_song)]       [Boyz II Men]
# 99          [/wiki/I_Can%27t_Make_You_Love_Me]      [Bonnie Raitt]
# 1                        [/wiki/Baby_Got_Back]     [Sir Mix-a-Lot]
# 2               [/wiki/Jump_(Kris_Kross_song)]        [Kris Kross]
# 3               [/wiki/Save_the_Best_for_Last]  [Vanessa Williams]
#
#                             URL
# 0           [/wiki/Boyz_II_Men]
# 99         [/wiki/Bonnie_Raitt]
# 1         [/wiki/Sir_Mix-a-Lot]
# 2            [/wiki/Kris_Kross]
# 3   [/wiki/Vanessa_L._Williams]

# %%
# Here we are populating the url cache
#Note that this function will take around 20 minutes to run as we are requestinf for several pages
#This function is designed to be run again and again: it just tries to make sure that there are no unresolved pages left. 
flatframe["URL"].apply(get_page)
# Out:
# /wiki/Boyz_II_Men
# /wiki/Bonnie_Raitt
# /wiki/Sir_Mix-a-Lot
# /wiki/Kris_Kross
# /wiki/Vanessa_L._Williams
# /wiki/TLC_(band)
# /wiki/Eric_Clapton
# /wiki/En_Vogue
# /wiki/Red_Hot_Chili_Peppers
# /wiki/Color_Me_Badd
# /wiki/Jon_Secada
# /wiki/Shanice
# /wiki/Mr._Big_(band)
# /wiki/Right_Said_Fred
# /wiki/Michael_Jackson
# /wiki/Billy_Ray_Cyrus
# /wiki/Mariah_Carey
# /wiki/Guns_N%27_Roses
# /wiki/Tom_Cochrane
# /wiki/Michael_Jackson
# /wiki/CeCe_Peniston
# /wiki/Madonna
# /wiki/Patty_Smyth
# /wiki/Mariah_Carey
# /wiki/House_of_Pain
# /wiki/Prince_(entertainer)
# /wiki/Atlantic_Starr
# /wiki/Celine_Dion
# /wiki/En_Vogue
# /wiki/Joe_Public_(band)
# /wiki/Jodeci
# /wiki/Nirvana_(band)
# /wiki/Bobby_Brown
# /wiki/Sophie_B._Hawkins
# /wiki/Tevin_Campbell
# /wiki/TLC_(band)
# /wiki/Boyz_II_Men
# /wiki/Technotronic
# /wiki/Queen_(band)
# /wiki/Arrested_Development_(group)
# /wiki/Luther_Vandross
# /wiki/Mariah_Carey
# /wiki/Elton_John
# /wiki/P.M._Dawn
# /wiki/Shakespears_Sister
# /wiki/MC_Hammer
# /wiki/KWS_(band)
# /wiki/Mint_Condition
# /wiki/The_Cover_Girls
# /wiki/George_Michael
# /wiki/P.M._Dawn
# /wiki/Bryan_Adams
# /wiki/Michael_Bolton
# /wiki/Genesis_(band)
# /wiki/Richard_Marx
# /wiki/U2
# /wiki/George_Michael
# /wiki/U2
# /wiki/CeCe_Peniston
# /wiki/Genesis_(band)
# /wiki/Karyn_White
# /wiki/The_Heights_(American_TV_series)
# /wiki/Kris_Kross
# /wiki/Celine_Dion
# /wiki/Ugly_Kid_Joe
# /wiki/The_Cure
# /wiki/Bryan_Adams
# /wiki/Paula_Abdul
# /wiki/Genesis_(band)
# /wiki/Arrested_Development_(group)
# /wiki/Michael_Jackson
# /wiki/Marky_Mark_and_the_Funky_Bunch
# /wiki/Amy_Grant
# /wiki/Toad_the_Wet_Sprocket
# /wiki/Boyz_II_Men
# /wiki/Snap!
# /wiki/Michael_Bolton
# /wiki/N2Deep
# /wiki/Kathy_Troccoli
# /wiki/Def_Leppard
# /wiki/Richard_Marx
# /wiki/FireHouse_(band)
# /wiki/Jade_(American_band)
# /wiki/Def_Leppard
# /wiki/Mary_J._Blige
# /wiki/The_KLF
# /wiki/Das_EFX
# /wiki/MC_Hammer
# /wiki/Color_Me_Badd
# /wiki/Charles_%26_Eddie
# /wiki/Amy_Grant
# /wiki/Richard_Marx
# /wiki/En_Vogue
# /wiki/Keith_Sweat
# /wiki/Mr._Big_(band)
# /wiki/Amy_Grant
# /wiki/CeCe_Peniston
# /wiki/Hi-Five
# /wiki/Color_Me_Badd
# /wiki/Snap!
# /wiki/TLC_(band)
# /wiki/Celine_Dion
# /wiki/Kris_Kross
# /wiki/Vanessa_L._Williams
# /wiki/TLC_(band)
# /wiki/Eric_Clapton
# /wiki/En_Vogue
# /wiki/Red_Hot_Chili_Peppers
# /wiki/Color_Me_Badd
# /wiki/Jon_Secada
# /wiki/Shanice
# /wiki/Mr._Big_(band)
# /wiki/Right_Said_Fred
# /wiki/Michael_Jackson
# /wiki/Billy_Ray_Cyrus
# /wiki/Mariah_Carey
# /wiki/Guns_N%27_Roses
# /wiki/Tom_Cochrane
# /wiki/Michael_Jackson
# /wiki/CeCe_Peniston
# /wiki/Madonna
# /wiki/Patty_Smyth
# /wiki/Mariah_Carey
# /wiki/George_Michael
# /wiki/Prince_(entertainer)
# /wiki/The_Cover_Girls
# /wiki/Mint_Condition
# /wiki/Boyz_II_Men
# /wiki/Celine_Dion
# /wiki/En_Vogue
# /wiki/Joe_Public_(band)
# /wiki/Jodeci
# /wiki/Nirvana_(band)
# /wiki/Bobby_Brown
# /wiki/Sophie_B._Hawkins
# /wiki/Tevin_Campbell
# /wiki/TLC_(band)
# /wiki/Boyz_II_Men
# /wiki/Technotronic
# /wiki/Queen_(band)
# /wiki/Arrested_Development_(group)
# /wiki/Luther_Vandross
# /wiki/Mariah_Carey
# /wiki/Elton_John
# /wiki/P.M._Dawn
# /wiki/Shakespears_Sister
# /wiki/MC_Hammer
# /wiki/KWS_(band)
# /wiki/Atlantic_Starr
# /wiki/Hi-Five
# /wiki/House_of_Pain
# /wiki/Amy_Grant
# /wiki/Toad_the_Wet_Sprocket
# /wiki/Michael_Bolton
# /wiki/Genesis_(band)
# /wiki/Richard_Marx
# /wiki/U2
# /wiki/George_Michael
# /wiki/The_Heights_(American_TV_series)
# /wiki/Bryan_Adams
# /wiki/CeCe_Peniston
# /wiki/Genesis_(band)
# /wiki/MC_Hammer
# /wiki/Sir_Mix-a-Lot
# /wiki/Kris_Kross
# /wiki/Michael_Jackson
# /wiki/Arrested_Development_(group)
# /wiki/Genesis_(band)
# /wiki/Marky_Mark_and_the_Funky_Bunch
# /wiki/Bryan_Adams
# /wiki/The_Cure
# /wiki/Ugly_Kid_Joe
# /wiki/Paula_Abdul
# /wiki/P.M._Dawn
# /wiki/Karyn_White
# /wiki/Michael_Bolton
# /wiki/U2
# /wiki/Richard_Marx
# /wiki/Def_Leppard
# /wiki/N2Deep
# /wiki/FireHouse_(band)
# /wiki/Jade_(American_band)
# /wiki/Boyz_II_Men
# /wiki/Mary_J._Blige
# /wiki/The_KLF
# /wiki/TLC_(band)
# /wiki/Color_Me_Badd
# /wiki/Charles_%26_Eddie
# /wiki/Amy_Grant
# /wiki/Color_Me_Badd
# /wiki/En_Vogue
# /wiki/Richard_Marx
# /wiki/Bonnie_Raitt
# /wiki/Das_EFX
# /wiki/Def_Leppard
# /wiki/Kathy_Troccoli
# /wiki/Amy_Grant
# /wiki/Mr._Big_(band)
# /wiki/Keith_Sweat
# /wiki/CeCe_Peniston
# /wiki/Shai_(band)
# /wiki/Soul_Asylum
# /wiki/4_Non_Blondes
# /wiki/Whitney_Houston
# /wiki/Tag_Team_(group)
# /wiki/UB40
# /wiki/Janet_Jackson
# /wiki/Silk_(group)
# /wiki/SWV
# /wiki/Mariah_Carey
# /wiki/SWV
# /wiki/Snow_(musician)
# /wiki/Dr._Dre
# /wiki/Jade_(R%26B_group)
# /wiki/H-Town_(band)
# /wiki/Jodeci
# /wiki/Duice
# /wiki/Robin_S.
# /wiki/Peabo_Bryson
# /wiki/Janet_Jackson
# /wiki/Vanessa_L._Williams
# /wiki/Wreckx-n-Effect
# /wiki/Expos%C3%A9_(group)
# /wiki/Onyx_(hip_hop_group)
# /wiki/Snap!
# /wiki/The_Proclaimers
# /wiki/Bobby_Brown
# /wiki/SWV
# /wiki/Whitney_Houston
# /wiki/Arrested_Development_(group)
# /wiki/Rod_Stewart
# /wiki/Shanice
# /wiki/Duran_Duran
# /wiki/Tony!_Toni!_Ton%C3%A9!
# /wiki/Meat_Loaf
# /wiki/Spin_Doctors
# /wiki/Tina_Turner
# /wiki/P.M._Dawn
# /wiki/Whitney_Houston
# /wiki/Shai_(band)
# /wiki/Duran_Duran
# /wiki/P.M._Dawn
# /wiki/95_South
# /wiki/Naughty_by_Nature
# /wiki/Toni_Braxton
# /wiki/Michael_Jackson
# /wiki/Paperboy_(rapper)
# /wiki/Shai_(band)
# /wiki/Boyz_II_Men
# /wiki/Billy_Joel
# /wiki/Def_Leppard
# /wiki/Restless_Heart
# /wiki/Dr._Dre
# /wiki/Xscape_(band)
# /wiki/Tupac_Shakur
# /wiki/Bon_Jovi
# /wiki/Mary_J._Blige
# /wiki/Portrait_(band)
# /wiki/Aerosmith
# /wiki/Ugly_Kid_Joe
# /wiki/TLC_(group)
# /wiki/Brian_McKnight
# /wiki/Cypress_Hill
# /wiki/Madonna
# /wiki/Jeremy_Jordan_(singer,_born_1973)
# /wiki/Inner_Circle_(reggae_band)
# /wiki/Boy_Krazy
# /wiki/Jon_Secada
# /wiki/Jon_Secada
# /wiki/Kenny_G
# /wiki/Janet_Jackson
# /wiki/Madonna
# /wiki/Ace_of_Base
# /wiki/Zhan%C3%A9
# /wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince
# /wiki/Positive_K
# /wiki/Inner_Circle_(reggae_band)
# /wiki/Ice_Cube
# /wiki/Taylor_Dayne
# /wiki/Captain_Hollywood_Project
# /wiki/The_Heights_(American_TV_series)
# /wiki/Digable_Planets
# /wiki/Haddaway
# /wiki/Michael_Bolton
# /wiki/Kris_Kross
# /wiki/Ice_Cube
# /wiki/Sting_(musician)
# /wiki/Dino_(singer)
# /wiki/En_Vogue
# /wiki/Jade_(American_band)
# /wiki/Rod_Stewart
# /wiki/Tears_for_Fears
# /wiki/Joey_Lawrence
# /wiki/Green_Jell%C3%BF
# /wiki/Aerosmith
# /wiki/Gin_Blossoms
# /wiki/Sting_(musician)
# /wiki/Tony!_Toni!_Ton%C3%A9!
# /wiki/Go_West_(band)
# /wiki/Prince_(musician)
# /wiki/Ace_of_Base
# /wiki/Bryan_Adams
# /wiki/Toni_Braxton
# /wiki/Lisa_Loeb
# /wiki/Jon_Secada
# /wiki/C%C3%A9line_Dion
# /wiki/Boyz_II_Men
# /wiki/All-4-One
# /wiki/Ace_of_Base
# /wiki/Mariah_Carey
# /wiki/R._Kelly
# /wiki/Warren_G
# /wiki/Madonna
# /wiki/Salt-n-Pepa
# /wiki/John_Mellencamp
# /wiki/Mariah_Carey
# /wiki/Toni_Braxton
# /wiki/Elton_John
# /wiki/Prince_(musician)
# /wiki/Coolio
# /wiki/Big_Mountain_(band)
# /wiki/Aaliyah
# /wiki/Janet_Jackson
# /wiki/Ace_of_Base
# /wiki/Da_Brat
# /wiki/Beck
# /wiki/The_Cranberries
# /wiki/All-4-One
# /wiki/Salt-n-Pepa
# /wiki/Janet_Jackson
# /wiki/Collective_Soul
# /wiki/Michael_Bolton
# /wiki/Enigma_(German_band)
# /wiki/Bryan_Adams
# /wiki/Sheryl_Crow
# /wiki/Crash_Test_Dummies
# /wiki/Babyface_(musician)
# /wiki/Tevin_Campbell
# /wiki/Meat_Loaf
# /wiki/DRS_(group)
# /wiki/10,000_Maniacs
# /wiki/Us3
# /wiki/Melissa_Etheridge
# /wiki/Changing_Faces_(group)
# /wiki/Tevin_Campbell
# /wiki/Crystal_Waters
# /wiki/Mariah_Carey
# /wiki/Janet_Jackson
# /wiki/Tag_Team_(group)
# /wiki/Richard_Marx
# /wiki/Brandy_Norwood
# /wiki/The_Four_Seasons_(band)
# /wiki/Gabrielle_(singer)
# /wiki/Bruce_Springsteen
# /wiki/Domino_(rapper)
# /wiki/Luther_Vandross
# /wiki/Aaron_Hall_(musician)
# /wiki/Xscape_(band)
# /wiki/Warren_G
# /wiki/Jodeci
# /wiki/Tupac_Shakur
# /wiki/Snoop_Dogg
# /wiki/IMx
# /wiki/R._Kelly
# /wiki/Aaliyah
# /wiki/69_Boyz
# /wiki/Erasure
# /wiki/Aerosmith
# /wiki/Meat_Loaf
# /wiki/Zhan%C3%A9
# /wiki/Xscape_(band)
# /wiki/Aerosmith
# /wiki/Babyface_(musician)
# /wiki/Real_McCoy_(band)
# /wiki/Culture_Beat
# /wiki/Jimmy_Cliff
# /wiki/SWV
# /wiki/Gin_Blossoms
# /wiki/Joshua_Kadison
# /wiki/Eternal_(band)
# /wiki/Craig_Mack
# /wiki/Queen_Latifah
# /wiki/Seal_(musician)
# /wiki/Madonna
# /wiki/Phil_Collins
# /wiki/Tim_McGraw
# /wiki/Heavy_D
# /wiki/Tim_McGraw
# /wiki/Ini_Kamoze
# /wiki/Bon_Jovi
# /wiki/Melissa_Etheridge
# /wiki/Ahmad_(rapper)
# /wiki/Snoop_Dogg
# /wiki/Bonnie_Raitt
# /wiki/General_Public
# /wiki/Tevin_Campbell
# /wiki/Haddaway
# /wiki/Babyface_(musician)
# /wiki/Ice_Cube
# /wiki/Tom_Petty_and_the_Heartbreakers
# /wiki/Madonna
# /wiki/Mariah_Carey
# /wiki/Real_McCoy_(band)
# /wiki/Coolio
# /wiki/Seal_(musician)
# /wiki/TLC_(band)
# /wiki/TLC_(band)
# /wiki/Monica_(singer)
# /wiki/Boyz_II_Men
# /wiki/Montell_Jordan
# /wiki/Michael_Jackson
# /wiki/The_Notorious_B.I.G.
# /wiki/Adina_Howard
# /wiki/Blues_Traveler
# /wiki/All-4-One
# /wiki/Bryan_Adams
# /wiki/Bon_Jovi
# /wiki/Shaggy_(musician)
# /wiki/Nicki_French
# /wiki/Des%27ree
# /wiki/Dionne_Farris
# /wiki/Boyz_II_Men
# /wiki/Ini_Kamoze
# /wiki/Sophie_B._Hawkins
# /wiki/Hootie_%26_the_Blowfish
# /wiki/Hootie_%26_the_Blowfish
# /wiki/Blessid_Union_of_Souls
# /wiki/TLC_(band)
# /wiki/Janet_Jackson
# /wiki/Sheryl_Crow
# /wiki/Vanessa_L._Williams
# /wiki/Jon_B.
# /wiki/Hootie_%26_the_Blowfish
# /wiki/Brownstone_(group)
# /wiki/Martin_Page
# /wiki/Boyz_II_Men
# /wiki/Luniz
# /wiki/Real_McCoy_(band)
# /wiki/MoKenStef
# /wiki/Collective_Soul
# /wiki/Soul_for_Real
# /wiki/Diana_King
# /wiki/Melissa_Etheridge
# /wiki/Soul_for_Real
# /wiki/Blackstreet
# /wiki/The_Notorious_B.I.G.
# /wiki/4_P.M._(group)
# /wiki/Method_Man
# /wiki/Brandy_Norwood
# /wiki/Brandy_Norwood
# /wiki/Tupac_Shakur
# /wiki/69_Boyz
# /wiki/Jade_(American_group)
# /wiki/Corona_(group)
# /wiki/Del_Amitri
# /wiki/Michael_Jackson
# /wiki/Jodeci
# /wiki/Skee-Lo
# /wiki/Elton_John
# /wiki/Natalie_Merchant
# /wiki/Tom_Petty
# /wiki/Vanessa_L._Williams
# /wiki/Take_That
# /wiki/Janet_Jackson
# /wiki/Real_McCoy_(band)
# /wiki/Groove_Theory
# /wiki/Junior_M.A.F.I.A.
# /wiki/Madonna
# /wiki/Bon_Jovi
# /wiki/Naughty_by_Nature
# /wiki/Subway_(group)
# /wiki/Sheryl_Crow
# /wiki/Total_(band)
# /wiki/Dr._Dre
# /wiki/Gloria_Estefan
# /wiki/Van_Halen
# /wiki/Jamie_Walters
# /wiki/Bone_Thugs-n-Harmony
# /wiki/Annie_Lennox
# /wiki/Faith_Evans
# /wiki/IMx
# /wiki/U2
# /wiki/Crystal_Waters
# /wiki/Brandy_(entertainer)
# /wiki/AZ_(rapper)
# /wiki/Better_Than_Ezra
# /wiki/D%27Angelo
# /wiki/After_7
# /wiki/Raphael_Saadiq
# /wiki/20_Fingers
# /wiki/FireHouse
# /wiki/Stevie_B
# /wiki/Rednex
# /wiki/Boyz_II_Men
# /wiki/The_Pretenders
# /wiki/N_II_U
# /wiki/Da_Brat
# /wiki/Brandy_Norwood
# /wiki/Soul_Asylum
# /wiki/Melissa_Etheridge
# /wiki/Donna_Lewis
# /wiki/Bone_Thugs-n-Harmony
# /wiki/Tracy_Chapman
# /wiki/Mariah_Carey
# /wiki/Mariah_Carey
# /wiki/Celine_Dion
# /wiki/Mariah_Carey
# /wiki/Los_del_R%C3%ADo
# /wiki/Tony_Rich
# /wiki/Toni_Braxton
# /wiki/Whitney_Houston
# /wiki/Quad_City_DJ%27s
# /wiki/Everything_but_the_Girl
# /wiki/Whitney_Houston
# /wiki/Gin_Blossoms
# /wiki/Brandy_Norwood
# /wiki/2Pac
# /wiki/Celine_Dion
# /wiki/Eric_Clapton
# /wiki/LL_Cool_J
# /wiki/LL_Cool_J
# /wiki/Jann_Arden
# /wiki/Keith_Sweat
# /wiki/La_Bouche
# /wiki/Monica_(singer)
# /wiki/Jewel_(singer)
# /wiki/Hootie_%26_the_Blowfish
# /wiki/112_(band)
# /wiki/Coolio
# /wiki/Mary_J._Blige
# /wiki/No_Mercy_(pop_band)
# /wiki/Joan_Osborne
# /wiki/Alanis_Morissette
# /wiki/Dishwalla
# /wiki/R._Kelly
# /wiki/SWV
# /wiki/Alanis_Morissette
# /wiki/R._Kelly
# /wiki/La_Bouche
# /wiki/Deep_Blue_Something
# /wiki/Coolio
# /wiki/Collective_Soul
# /wiki/Blackstreet
# /wiki/3T
# /wiki/The_Smashing_Pumpkins
# /wiki/TLC_(band)
# /wiki/Monica_(singer)
# /wiki/Goo_Goo_Dolls
# /wiki/Total_(group)
# /wiki/Natalie_Merchant
# /wiki/Seal_(musician)
# /wiki/Natalie_Merchant
# /wiki/Merril_Bainbridge
# /wiki/Color_Me_Badd
# /wiki/Joe_(singer)
# /wiki/Oasis_(band)
# /wiki/Busta_Rhymes
# /wiki/Groove_Theory
# /wiki/Outkast
# /wiki/Blues_Traveler
# /wiki/George_Michael
# /wiki/Az_Yet
# /wiki/Kris_Kross
# /wiki/Aaliyah
# /wiki/Ginuwine
# /wiki/John_Mellencamp
# /wiki/D%27Angelo
# /wiki/Keith_Sweat
# /wiki/No_Doubt
# /wiki/BoDeans
# /wiki/Adam_Clayton
# /wiki/Robert_Miles
# /wiki/Junior_M.A.F.I.A.
# /wiki/Hootie_%26_the_Blowfish
# /wiki/Case_(singer)
# /wiki/LL_Cool_J
# /wiki/Total_(group)
# /wiki/Sheryl_Crow
# /wiki/Deborah_Cox
# /wiki/Toni_Braxton
# /wiki/Amber_(performer)
# /wiki/R._Kelly
# /wiki/Janet_Jackson
# /wiki/Planet_Soul
# /wiki/New_Edition
# /wiki/Ghost_Town_DJ%27s
# /wiki/Maxi_Priest
# /wiki/Sophie_B._Hawkins
# /wiki/Melissa_Etheridge
# /wiki/Metallica
# /wiki/Do_or_Die_(group)
# /wiki/Madonna
# /wiki/Hootie_%26_the_Blowfish
# /wiki/Los_del_R%C3%ADo
# /wiki/Faith_Evans
# /wiki/MC_Lyte
# /wiki/Take_That
# /wiki/Ace_of_Base
# /wiki/Crucial_Conflict
# /wiki/Pearl_Jam
# /wiki/Spice_Girls
# /wiki/Sean_Combs
# /wiki/Toni_Braxton
# /wiki/Sean_Combs
# /wiki/R._Kelly
# /wiki/En_Vogue
# /wiki/Jewel_(singer)
# /wiki/Mark_Morrison
# /wiki/LeAnn_Rimes
# /wiki/Backstreet_Boys
# /wiki/Third_Eye_Blind
# /wiki/Rome_(musician)
# /wiki/Usher_(entertainer)
# /wiki/Meredith_Brooks
# /wiki/Keith_Sweat
# /wiki/Duncan_Sheik
# /wiki/Az_Yet
# /wiki/The_Notorious_B.I.G.
# /wiki/The_Verve_Pipe
# /wiki/Savage_Garden
# /wiki/Hanson_(band)
# /wiki/Monica_(singer)
# /wiki/Elton_John
# /wiki/Blackstreet
# /wiki/Celine_Dion
# /wiki/112_(band)
# /wiki/Spice_Girls
# /wiki/Robyn
# /wiki/Boyz_II_Men
# /wiki/Changing_Faces_(group)
# /wiki/Mariah_Carey
# /wiki/Whitney_Houston
# /wiki/Dru_Hill
# /wiki/Freak_Nasty
# /wiki/Spice_Girls
# /wiki/Babyface_(musician)
# /wiki/Sister_Hazel
# /wiki/Paula_Cole
# /wiki/Shawn_Colvin
# /wiki/Tim_McGraw
# /wiki/Gina_G
# /wiki/Allure_(group)
# /wiki/New_Edition
# /wiki/98_Degrees
# /wiki/Lil%27_Kim
# /wiki/Bone_Thugs-n-Harmony
# /wiki/702_(band)
# /wiki/Merril_Bainbridge
# /wiki/Celine_Dion
# /wiki/The_Notorious_B.I.G.
# /wiki/Somethin%27_for_the_People
# /wiki/Montell_Jordan
# /wiki/Sarah_McLachlan
# /wiki/Total_(band)
# /wiki/Barbra_Streisand
# /wiki/Foxy_Brown_(rapper)
# /wiki/Sheryl_Crow
# /wiki/Dru_Hill
# /wiki/Journey_(band)
# /wiki/Toni_Braxton
# /wiki/Sheryl_Crow
# /wiki/No_Mercy_(pop_band)
# /wiki/MC_Lyte
# /wiki/Timbaland_%26_Magoo
# /wiki/Donna_Lewis
# /wiki/Coolio
# /wiki/Eric_Clapton
# /wiki/Heavy_D
# /wiki/B-Rock_and_the_Bizz
# /wiki/Chumbawamba
# /wiki/R._Kelly
# /wiki/Az_Yet
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-5f86b0f7fb15> in <module>
#       2 #Note that this function will take around 20 minutes to run as we are requestinf for several pages
#       3 #This function is designed to be run again and again: it just tries to make sure that there are no unresolved pages left.
# ----> 4 flatframe["URL"].apply(get_page)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-70-9004a389b512> in get_page(url)
#       1 urlcache={}
#       2 def get_page(url):
# ----> 3     url = url[0]
#       4     print(url)
#       5     if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
#
# IndexError: list index out of range

# %%
#Let us make sure that there are no unresolved pages
#The sum below should be 0, and the boolean True. If that is not the case, run the above cell again until you get a sum of 0 and a boolean True
print (np.sum([(urlcache[k]==1) or (urlcache[k]==2) and isinstance(k,str) for k in urlcache]))
print (len(flatframe.URL.unique())==len(urlcache))#we got all of the urls
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-ab5e9c31729b> in <module>
#       2 #The sum below should be 0, and the boolean True. If that is not the case, run the above cell again until you get a sum of 0 and a boolean True
#       3 print (np.sum([(urlcache[k]==1) or (urlcache[k]==2) and isinstance(k,str) for k in urlcache]))
# ----> 4 print (len(flatframe.URL.unique())==len(urlcache))#we got all of the urls
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    1866         Categories (3, object): ['a' < 'b' < 'c']
#    1867         """
# -> 1868         result = super().unique()
#    1869         return result
#    1870
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#    1263                     result = np.asarray(result)
#    1264         else:
# -> 1265             result = unique1d(values)
#    1266
#    1267         return result
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     387
#     388     table = htable(len(values))
# --> 389     uniques = table.unique(values)
#     390     uniques = _reconstruct_data(uniques, original.dtype, original)
#     391     return uniques
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
#Let's save the `urlcache` and remove the old object. 
keys_values = urlcache.items()
urlcache = {str(key): str(value) for key, value in keys_values}
with open("artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %%
with open("/content/gdrive/MyDrive/DS-1 /HW-1/artistinfo.json") as json_file:
    urlcache = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-76-ad4d87e86e23> in <module>
# ----> 1 with open("/content/gdrive/MyDrive/DS-1 /HW-1/artistinfo.json") as json_file:
#       2     urlcache = json.load(json_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/DS-1 /HW-1/artistinfo.json'

# %% [markdown]
# ### 3.2 Parse the data

# %% [markdown]
# Now, we need to extract the following information from each page. Write a function `singer_band_info(url, page_text)` that returns a dictionary.
#
# Here `url` should be the path the url corresponding to the singer's Wikipedia page (same as the previous dataframe `flatframe`), and page_text should be the HTML text for the corresponding artist's webpage.
#
# This function should return a dictionary which contains the following information:
#
# 1. The genres of the band or singer. These genres should be urls, to ensure their uniqueness. Create a list, `genres`, of these urls. If there are no genres, use `['NA']`.
#
# 2. If the page has the text "Born", extract the element with the class `.bday`. If there is no "Born", store `False`. Store either of these into the variable `born`.
#
# 3. If the text "Years active" is found, but there is no birthday, assume a band. Store the years active into the variable `ya`, or `False` if the text is not found.
#
# The information can be found below the artists image on each such wikipedia page, as the example here shows:
#
#
# ![EdSheeran](https://drive.google.com/uc?export=view&id=1NJi2C-Gi5HPziuPxefNcjj5i4-04kuQ-)

# %% [markdown]
# The dictionary returned should be of the form:
# ```
# { 'url': '/wiki/Boyz_II_Men',
# 'genres': ['/wiki/Contemporary_R%26B_music', '/wiki/Soul_music', '/wiki/New_jack_swing'],
# 'born': None,
# 'ya': '1987–present'}
# ```
#
# Wikipedia has changed it's format along the years! So observing one artist's webpage and building your function based on it will probably give you tons of errors.
#
# Here are a few issues to remember while parsing:
#
# 1.   There are several artists that take a sabbatical between their active years (https://en.wikipedia.org/wiki/Tony!_Toni!_Ton%C3%A9!). To get the right data, write a function to calculate the longest period of time they were active and consider that as your variable `years active`. In the example give, this would be 2003–present.
# 2.   Birthday's are given in different formats for different pages. For example - https://en.wikipedia.org/wiki/Sir_Mix-a-Lot and https://en.wikipedia.org/wiki/Ed_Sheeran have different formats. To ensure that you get the right day, look for the 'span' tag with a 'bday' tag and ensure that there are no paranthesis around the extracted text.
# 3. Year's active are also given in different formats. For example - https://en.wikipedia.org/wiki/Boyz_II_Men and https://en.wikipedia.org/wiki/Ed_Sheeran are different. You could use regex ("[0-9]{4}[–][0-9]{4}" and "[0-9]{4}[–][0-9]{4}") to ensure you are getting the right years.<br> Report the edge cases found and why the Regex expression takes care of all these edge cases.
#
# Definitely do look at your outputs as you are parsing as it can identify several edge cases you have not considered in your code.

# %% [markdown]
# Before parsing, it is important to note that Wikipedia has defined the same genre in a few different ways. Our parsing code will pick these up as different and new as they all differ with the alphabet case or an underscore instead of a hyphen.
#
# We have defined a function to ensure that we have the correct representation of the number of artists in a particular genre.

# %%
genres_duplicates={'/wiki/Adult_Contemporary_music':'/wiki/Adult_contemporary','/wiki/Adult_contemporary_music':'/wiki/Adult_contemporary',
'/wiki/Afrobeat':'/wiki/Afrobeats',
'/wiki/Alternative_rock':'/wiki/Alternative_Rock',
'/wiki/Avant-garde':'/wiki/Avant-garde_music',
'/wiki/Blues':'/wiki/Blues_music',
'/wiki/Comedy_hip-hop':'/wiki/Comedy_hip_hop',
'/wiki/Contemporary_R%26B':'/wiki/Contemporary_R%26B_music',
'/wiki/Contemporary_folk':'/wiki/Contemporary_folk_music',
'/wiki/Country_Folk':'/wiki/Country_folk',
'/wiki/Dance_pop':'/wiki/Dance-pop',
'/wiki/East_Coast_hip_hop':'/wiki/East_coast_hip_hop',
'/wiki/Electronic_Dance_Music':'/wiki/Electronic_dance_music',
'/wiki/Electronica':'/wiki/Electronica_music',
'/wiki/Emo':'/wiki/Emo_music',
'/wiki/Electropop':'/wiki/Electro-pop',
'/wiki/Folk-pop':'/wiki/Folk_pop',
'/wiki/Funk':'/wiki/Funk_music',
'/wiki/Grime_(music_genre)':'/wiki/Grime_music',
'/wiki/Gangsta_Rap':'/wiki/Gangsta_rap',
'/wiki/Hip_Hop_music': '/wiki/Hip_hop','/wiki/Hip_hop_music':'/wiki/Hip_hop',
'/wiki/Hyphy':'/wiki/Hyphy_music',
'/wiki/Latin_music':'/wiki/Latin_music_(genre)',
'/wiki/West_Coast_hip_hop':'/wiki/West_coast_hip_hop',
'/wiki/Southern_Hip_Hop':'/wiki/Southern_hip_hop',
'/wiki/Ska':'/wiki/Ska_music',
'/wiki/Pop-rock':'/wiki/Pop_rock',
'/wiki/Pop_Music':'/wiki/Pop_music',
'/wiki/Nu_metal':'/wiki/Nu_metal_music'}

def genre_duplicates(genres):
    for i in range(len(genres)):
        if genres[i] in genres_duplicates.keys():
            genres[i]=genres_duplicates[genres[i]]
    return genres

# %% [markdown]
# Define a function to calculate the longest active years

# %%
#your code here

# %% [markdown]
# Please write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    genres: the genres that the band or singer works in
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""

#your code here

def singer_band_info(url, page_text):
    thisDict = dict()

# %% [markdown]
# Let's iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a list.
#
# Each element in this list is the dictionary that the function `singer_band_info` returns.
#
# The list should look something like this:
# ```
#   'genres': ['/wiki/Contemporary_R%26B_music',
#    '/wiki/Soul_music',
#    '/wiki/New_jack_swing'],
#   'url': '/wiki/Boyz_II_Men',
#   'ya': '1987–present'},
#  {'born': None,
#   'genres': ['/wiki/Pop_music',
#    '/wiki/Electronica_music',
#    '/wiki/Dance_music',
#    '/wiki/Rave_music',
#    '/wiki/House_music'],
#   'url': '/wiki/KWS_(band)',
#   'ya': '1991–1994'},
#  ... and so on]
#   ```

# %%
#your code here

# %%
#Store the list and delete the variable
with open("singer_band_info_list.json","w") as fd:
    json.dump(singer_band_info_list, fd)
del singer_band_info_list

# %%
#Load the list into a variable
with open("/content/gdrive/MyDrive/DS-1 /HW-1/singer_band_info.json") as json_file:
    singer_band_info_list = json.load(json_file)

# %% [markdown]
# Create a dataframe from the list `singer_band_info_list`.

# %%
#your code here

# %% [markdown]
# ## Q4: Merging Artist's and Song dataframes
# #### [15 points]

# %% [markdown]
# Now, merge the artist/song data frames into one large dataframe. Note that this has an effect of imputing to a song **all the genres** that the artist is active in. We know that this is not true, but it is the simplest assumption we can make, and is probably good for most artists.

# %%
#your code here

# %% [markdown]
# Update the dataframe by adding a column for each genre with 1-0 encoding for each row. This means, we want columns like "/wiki/Alternative_Rock", "/wiki/Acid_jazz", where if an artist is in that genre, the dataframe cell has a 1. Otherwise, it has a 0.
#
# Remember that an artist/band can be in multiple genres, and must have a 1 for each column corresponding to these genres, and 0 otherwise.
#
# This will widen the dataframe by the total number of genres that we have. The expanded part will look a bit like this:
#
# ![largedfexample](https://drive.google.com/uc?export=view&id=1YgIVsyjWLXIAipI5dF2H4fvAmQodpE8L)

# %%
#your code here

# %% [markdown]
# Ensure the data types of the dataframe is correct

# %%
#your code here

# %%
#Store the dataframe to use in HW-2 
largedf.to_pickle('/content/largedf')
del largedf

# %%
#Loading in dataframe
largedf = pd.read_pickle('/content/gdrive/MyDrive/DS-1 /HW-1/largedf')
largedf.head()

# %% [markdown]
# ## Q5: Pandas and Relational databases
# #### [20 points]

# %% [markdown]
# ### 5.1 Populating the database

# %% [markdown]
# We use sqlite3 here. There is an even higher level API available, called SQLAlchemy.  However SQLite is built into Python and also has a command line tool and sqlite browser that you can install.

# %%
import sqlite3 as sql

# %% [markdown]
# Let us start by creating our schema to set the type of each column in our dataframe.

# %%
#your code here 
#ourschema=' '

# %% [markdown]
# Next, create a connection object which will connect us to the database and will let us execute the SQL statements.
# Create an object of the cursor using the connection object and execute our schema.
# Finally, use the `to_sql` function and convert our large expanded dataframe from the last section to a table.

# %%
#your code here

# %% [markdown]
# ### 5.2 Performing operations on the database

# %% [markdown]
# Answer the following questions by writing SQL statements.

# %% [markdown]
# #### 5.2.1 Select all singers below the age of 20 whos Zodiac Sign is Scorpio!

# %%
#your code here

# %% [markdown]
# #### 5.2.2 Find the most popular artists with most appearances in Billboard Top 10

# %%
#your code here

# %% [markdown]
# #### 5.2.3 Select all songs with ranking less than 6 and order the rows by artist name

# %%
#your code here
